# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import torchvision.models as models
import torchvision.transforms as transforms

from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader,Subset, Dataset,random_split

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from torch.utils.data import Dataset

import pandas as pd
import shutil

import matplotlib.pyplot as plt

from torchvision import models
from sklearn.metrics import fbeta_score
from sklearn.metrics import precision_score, recall_score

import os
from PIL import Image, ImageEnhance, ImageFilter
from tqdm import tqdm
from torchvision import transforms

# %%
# !curl -L -o Font_recognition.zip https://github.com/NextGen-AI-Camp/curriculum/releases/download/Workshop/Font_recognition.zip
# !unzip -o  /content/Font_recognition.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: images/9ac8a008-12f8-4eb9-a4ef-c2f2d78ccc4e.jpg
#   inflating: images/9adb4195-2a08-4a72-800b-0ceccdd92c56.jpg
#   inflating: images/9ae5ebcc-b744-458c-8ebc-c0bb00ded94a.jpg
#   inflating: images/9ae7c34f-e754-430a-af69-a269c82e0185.jpg
#   inflating: images/9aefd856-6027-4524-bf6b-585aaffc4f64.jpg
#   inflating: images/9af13c53-91e7-4dda-b880-f3d3fa0c3cc2.jpg
#   inflating: images/9afb1f5b-b579-4ea3-b6a8-11afe99c2ac0.jpg
#   inflating: images/9aff54d3-8d05-40e2-9961-0e497fdee70d.jpg
#   inflating: images/9b001318-5721-489f-956d-127dc01c4aba.jpg
#   inflating: images/9b116749-3595-40d6-b592-e78a8d534295.jpg
#   inflating: images/9b12ef52-33f7-431d-83a2-2b7ee3d55e76.jpg
#   inflating: images/9b157027-bb83-40c1-b61b-8bcce87a8c9b.jpg
#   inflating: images/9b1b93f3-4486-4f81-bc9c-22dc7e618e6f.jpg
#   inflating: images/9b1e81ed-04f0-4180-8ef3-051c94f64739.jpg
#   inflating: images/9b1f0e9e-db1c-48dd-835f-c61b1951a4b2.jpg
#   inflating: images/9b23284e-1261-44aa-abf9-3ed335c7ddb0.jpg
#   inflating: images/9b262220-512f-4803-ac62-9484b1bb14cf.jpg
#   inflating: images/9b28e4c9-c91b-4593-8e75-79c8afab489b.jpg
#   inflating: images/9b2a4256-3fcb-4f88-92d7-faf5eccd337a.jpg
#   inflating: images/9b2c84ce-3def-4823-beee-0fb627783dcb.jpg
#   inflating: images/9b3294ea-af73-4546-965d-d55396b1ccda.jpg
#   inflating: images/9b395be3-8367-462d-abaa-aea5ca1d2568.jpg
#   inflating: images/9b3a64e3-d097-4eff-b643-bdfe4921fddc.jpg
#   inflating: images/9b3bf132-90f3-46c8-8ce0-a1246b88de15.jpg
#   inflating: images/9b4893b9-f727-41f5-9df7-92a72761f297.jpg
#   inflating: images/9b49646d-88a4-4610-946d-b8c7272a8151.jpg
#   inflating: images/9b4a888c-66c5-4fae-9697-c05b43775640.jpg
#   inflating: images/9b51cb87-e036-4545-aa57-9170b4a7c492.jpg
#   inflating: images/9b55722e-1b64-4aaf-89dc-28c49e4a0575.jpg
#   inflating: images/9b5e31ce-0c37-4c69-8c2c-aaa85d5d9676.jpg
#   inflating: images/9b5ed327-686b-409c-8dfe-4b92749e8224.jpg
#   inflating: images/9b6b7370-e4f1-4ac5-99f4-d8de231b0ffc.jpg
#   inflating: images/9b6d41d9-d304-4bf9-a94e-6cb1c40e591b.jpg
#   inflating: images/9b6fefad-720c-4d46-8eff-13041a42a134.jpg
#   inflating: images/9b729439-c3e6-4a45-a936-d76179b168e0.jpg
#   inflating: images/9b75daed-9754-4208-b208-96cc75c55660.jpg
#   inflating: images/9b7ae900-98ab-4358-b87b-c8e45ca964a0.jpg
#   inflating: images/9b7eca4d-e63e-4a38-816b-452c6aa98acf.jpg
#   inflating: images/9b801d82-6481-4b08-b298-0fb210f43ce6.jpg
#   inflating: images/9b803f71-e339-41b7-90d0-5ec59203d7e8.jpg
#   inflating: images/9b917958-60df-45fa-a0de-3122a182e8d9.jpg
#   inflating: images/9b945b39-7d10-4614-8853-3a451a79532d.jpg
#   inflating: images/9b950ed8-fa5f-4739-aee6-2d1bc0932803.jpg
#   inflating: images/9b988bab-e8c3-444e-94ad-ad9e2befd0c7.jpg
#   inflating: images/9ba2c268-cad4-43b5-98ea-bf6181ad735a.jpg
#   inflating: images/9ba5bff5-6850-40c0-bfe3-21c676728620.jpg
#   inflating: images/9ba7a86a-6eda-4b1e-bc20-56bc846525d8.jpg
#   inflating: images/9ba9362a-76c8-4d92-8ee0-3137f072548f.jpg
#   inflating: images/9ba9d676-1337-4f1f-8458-9dcae418959a.jpg
#   inflating: images/9baacf6e-d1b2-470e-901b-4ccd81635b7a.jpg
#   inflating: images/9bb1ecc3-f3f9-474b-b18f-cd7e63cbfea3.jpg
#   inflating: images/9bb4d345-52dd-4fc1-bd6a-073d707f8680.jpg
#   inflating: images/9bb4d932-360e-451a-880d-183e65b78f42.jpg
#   inflating: images/9bbc8b52-e34f-4402-939f-97aafe5b5990.jpg
#   inflating: images/9bc1f9ea-0b1a-4dbc-8c3f-c12f9de884ea.jpg
#   inflating: images/9bca5335-edd3-4dc5-9540-3ca4e11bb4b5.jpg
#   inflating: images/9bccaed1-1e70-4d2b-b1d8-7490e4d9c52f.jpg
#   inflating: images/9bd07c62-399d-4de3-8c9a-af0ebf7bb475.jpg
#   inflating: images/9bd40619-1229-48ad-b22c-0ab01e810170.jpg
#   inflating: images/9bd5b271-02c7-40e8-ac92-db008b2570a7.jpg
#   inflating: images/9be71c8d-3432-4693-b972-f0c325748621.jpg
#   inflating: images/9be9daba-c280-4367-a07e-396df448cb54.jpg
#   inflating: images/9bed0d10-a784-4ac6-840e-914779b05c29.jpg
#   inflating: images/9bef1193-e649-47b3-a8f3-761b004e112c.jpg
#   inflating: images/9bf55245-3f11-41fb-880a-6202e00faac7.jpg
#   inflating: images/9bf636ac-00cc-41e0-9a8d-9bec2dc5d59d.jpg
#   inflating: images/9bfcd52e-69e2-4fc4-97ea-f4334ecbf452.jpg
#   inflating: images/9c09a432-0156-491a-bb61-274561f5315b.jpg
#   inflating: images/9c0a0e80-edc6-4804-92f6-9270e0b739ba.jpg
#   inflating: images/9c0e8275-43e7-42ec-88f8-2f617d2dfa27.jpg
#   inflating: images/9c16575a-b6eb-4e41-9d46-8785f1a2b4d2.jpg
#   inflating: images/9c1a0fd5-1d04-48c4-ac16-5deefbd1c51f.jpg
#   inflating: images/9c1a5c58-d39f-457a-80b0-ef8b23d8a90e.jpg
#   inflating: images/9c1cc98f-810a-45b5-9e90-b556881d9982.jpg
#   inflating: images/9c1d851c-1644-4e61-ab45-6ba97f3a0698.jpg
#   inflating: images/9c29ecb9-f9b4-4e45-a853-16acc3a242da.jpg
#   inflating: images/9c3451e9-576a-4b19-aeec-f173f7b4c4e8.jpg
#   inflating: images/9c382ab1-93c4-4c9f-8601-79b48613316c.jpg
#   inflating: images/9c3c3b13-039e-416c-9ac7-ec968526a787.jpg
#   inflating: images/9c420cbb-53cb-4762-bc72-239eddfd72e0.jpg
#   inflating: images/9c47467a-664b-430d-befa-f29ab2adbf17.jpg
#   inflating: images/9c47b28b-8ccc-4eeb-801c-762dbfc853f1.jpg
#   inflating: images/9c50b849-6415-462b-8924-b5e91f7b66fc.jpg
#   inflating: images/9c56a3d7-5b09-4c0e-9ba2-cc6e25498ab4.jpg
#   inflating: images/9c5b8885-3264-4f12-b795-3aeacd9b2e4a.jpg
#   inflating: images/9c5e8b04-fed7-44f7-9e31-58993a08a7f8.jpg
#   inflating: images/9c602b28-492a-4abe-88ea-1a7c62cae296.jpg
#   inflating: images/9c6b9c6d-5279-4d29-a9e3-dd6865f832cb.jpg
#   inflating: images/9c6c69d3-0d60-46b9-b5be-53662cebf594.jpg
#   inflating: images/9c70ef34-a1a5-44df-ab5f-82d2c8993cd6.jpg
#   inflating: images/9c753c1b-e178-4273-816d-465461b7f79c.jpg
#   inflating: images/9c79e691-dbcb-4dd3-8cf9-eedd4a4dab3c.jpg
#   inflating: images/9c856315-9ce6-4390-a6ad-a0c744dd6f07.jpg
#   inflating: images/9c874cad-89dd-4627-be82-b1c62fa74295.jpg
#   inflating: images/9c89045a-b5d8-4f7b-a545-b5bf502c2e57.jpg
#   inflating: images/9c8f2c26-6cd9-4ff6-96bd-83105e0daef2.jpg
#   inflating: images/9c96700a-a7bd-4bcc-876a-de598782e17c.jpg
#   inflating: images/9c96ce55-7e2b-499a-945a-d1a29548b8af.jpg
#   inflating: images/9c9c01e8-3d9f-4479-b113-049303f2a7ad.jpg
#   inflating: images/9ca18991-87bd-49e1-9d6b-6cbac0a338cb.jpg
#   inflating: images/9ca500b5-2ac9-4ed2-a9e8-d0e60514455a.jpg
#   inflating: images/9cb37147-a317-409a-b04b-49a2c0a71810.jpg
#   inflating: images/9cbb2d0a-d4ee-4d65-93fd-7ce057f11aa1.jpg
#   inflating: images/9cbeea2d-e43e-497e-89fd-e38e3573feaa.jpg
#   inflating: images/9cbfdfe2-3ed8-41f6-b7ca-70479e884295.jpg
#   inflating: images/9cc81605-7ca2-4061-9336-0bbf81cf58ce.jpg
#   inflating: images/9ccec3e8-d743-474a-bfff-4b5490f60bb0.jpg
#   inflating: images/9cd16d33-a068-4f68-b4cb-56112e582d51.jpg
#   inflating: images/9cd6dedd-20d5-4d05-a0e6-5a7d7bd9353b.jpg
#   inflating: images/9cd7016a-c0db-4655-95a9-ae6682b27432.jpg
#   inflating: images/9cd75991-33ce-486d-9fcf-dcdf05858045.jpg
#   inflating: images/9cda5894-ed25-4d90-b96d-732c85d6bb5b.jpg
#   inflating: images/9cda84c7-5536-4a49-a640-90239932f2b4.jpg
#   inflating: images/9cdd91f3-d821-48e5-aee6-a1b3ed8b5cff.jpg
#   inflating: images/9cdeb914-db92-4cbe-81ea-8bc1ba0b93cf.jpg
#   inflating: images/9ce13ee7-c9e8-4940-a9c4-4f9e9c550a9b.jpg
#   inflating: images/9ce19629-de0b-4fb3-bc9f-e7f811e6c7ec.jpg
#   inflating: images/9ce6239b-ab9c-4053-8247-d0345ce1b67b.jpg
#   inflating: images/9ce740ae-934e-4748-af5d-0c7dcc2e03ce.jpg
#   inflating: images/9ced9a85-9b5b-48f2-ac28-8a38b175f3e4.jpg
#   inflating: images/9cf2e2f4-158d-4325-a0b0-c5e13a0f9a41.jpg
#   inflating: images/9cf2ff61-6776-470f-9500-48ca21dd0585.jpg
#   inflating: images/9cfd73c7-c03e-44c0-8fb4-1fb2a1343abc.jpg
#   inflating: images/9d04ef0f-6358-40ed-a3c2-d850616073a4.jpg
#   inflating: images/9d0d6901-2f3b-4b02-9877-eb27c6c586b5.jpg
#   inflating: images/9d0e9402-c470-4157-bf89-a000168eccc9.jpg
#   inflating: images/9d1050a8-9f70-42a6-8e4b-974dfad5f1af.jpg
#   inflating: images/9d13b262-a6b7-406e-91a5-0e84e1906fd9.jpg
#   inflating: images/9d1637f9-af91-45d4-b7c7-dc5880dfdf40.jpg
#   inflating: images/9d16a25d-ab1b-4189-971c-9adecb5077db.jpg
#   inflating: images/9d1c71c0-7b97-4cf8-abe7-fd40a79e2941.jpg
#   inflating: images/9d1cb8c6-61fe-4a23-9a4b-3b3a789ba649.jpg
#   inflating: images/9d1d22f2-38e5-4e42-b663-bda04c534583.jpg
#   inflating: images/9d307220-b96f-4491-9028-3ec09a0c01bb.jpg
#   inflating: images/9d30d473-6be6-4f68-b2ee-6378930bc9fb.jpg
#   inflating: images/9d34b0e8-42bc-4f0a-8588-6fb684244a33.jpg
#   inflating: images/9d3dc191-7b9c-4f68-8dff-a15bc3e99e80.jpg
#   inflating: images/9d3df5e0-c852-46f5-a057-2b280d36574d.jpg
#   inflating: images/9d3fff30-6905-4c69-bf7c-8b917acb4555.jpg
#   inflating: images/9d410a85-e49c-45e6-9b6e-6f09c2786601.jpg
#   inflating: images/9d456648-3559-41d2-9870-0eda3ff06413.jpg
#   inflating: images/9d4dc57e-8369-4326-a8b5-e849ac7cf455.jpg
#   inflating: images/9d4df3df-921f-491e-b0b5-4d821a337656.jpg
#   inflating: images/9d4ee615-4e9d-4a36-ae1a-ae281c2c1a94.jpg
#   inflating: images/9d5d7605-b25d-4452-98a3-6c1e6300752a.jpg
#   inflating: images/9d5f3140-41f3-443b-af0f-55542e6cd16f.jpg
#   inflating: images/9d6604cd-d524-484d-9860-2f5d8a0ca437.jpg
#   inflating: images/9d6fc43f-8157-459a-b68f-5e7e0657f5ec.jpg
#   inflating: images/9d773619-f7f8-4677-ae26-d75d9674af16.jpg
#   inflating: images/9d77536e-9b78-49a2-bc8c-f5176da31ab7.jpg
#   inflating: images/9d97f151-71cd-4b51-a282-94a23af593d7.jpg
#   inflating: images/9d9b228d-5021-43db-8cbe-3809703aa356.jpg
#   inflating: images/9d9bdb22-0c3d-4242-a89c-f6dcbdb072c4.jpg
#   inflating: images/9d9d8cf3-f1a4-497d-a92b-908da92aa2d7.jpg
#   inflating: images/9da57564-02fc-49e7-a418-c1a74df0ae07.jpg
#   inflating: images/9dadd690-6b22-4dd3-8c56-78ae14132bd1.jpg
#   inflating: images/9db07b0c-7baa-426d-8c0d-73aec29f2b0a.jpg
#   inflating: images/9db1780b-b015-431c-8c27-68f94ee92cea.jpg
#   inflating: images/9dbd3516-2b34-4582-b80b-89340ace594f.jpg
#   inflating: images/9dc2387a-48d9-4a93-ad92-94167ee72fb7.jpg
#   inflating: images/9dcb1d85-2ef0-42d2-82e6-00d0e16e1d2f.jpg
#   inflating: images/9dd005c1-071c-4da2-89ea-7b76f62e6c14.jpg
#   inflating: images/9dd0c5f1-1508-46e2-8119-4405814f8bf5.jpg
#   inflating: images/9dd7a1f9-d5d6-406d-affb-6969d38941bc.jpg
#   inflating: images/9de74592-4b26-464a-9b63-520628427481.jpg
#   inflating: images/9de75b0e-fe0b-4bf6-895c-c8087842cc15.jpg
#   inflating: images/9de9b88c-7172-46cb-8610-e4a32900f566.jpg
#   inflating: images/9df068b2-8d0b-4077-bc50-954910210a7d.jpg
#   inflating: images/9df4da97-1029-4404-a10b-f1fba3c788cf.jpg
#   inflating: images/9df52ef5-29b6-455a-912c-cb99dd992f9a.jpg
#   inflating: images/9df751dd-f09f-4db3-80fd-066ad23490b7.jpg
#   inflating: images/9e02ee70-95dd-4d20-bf70-023a1667fa30.jpg
#   inflating: images/9e10fe64-48ee-4c3a-aa0d-3539df23f578.jpg
#   inflating: images/9e1475f4-a336-4d3e-a42e-befb862b227c.jpg
#   inflating: images/9e16e078-e645-4723-9873-d09cef515da8.jpg
#   inflating: images/9e181bcb-4229-4f51-a04c-e72fe28faf89.jpg
#   inflating: images/9e1b27a9-c7ef-4d6b-bcfc-96c25302f7c7.jpg
#   inflating: images/9e20ff15-3bcb-448c-b578-eab7ca990f28.jpg
#   inflating: images/9e2438d0-58a5-4952-9913-8bcb4ee3033d.jpg
#   inflating: images/9e26476b-6499-46e4-9468-23cda3eab310.jpg
#   inflating: images/9e2fb590-6733-49f0-bf4c-475f786723e5.jpg
#   inflating: images/9e3045e9-0401-4206-aef3-85b3b40466af.jpg
#   inflating: images/9e345798-2cac-404a-b715-aea5058d5ef0.jpg
#   inflating: images/9e365448-658d-4f7b-a1ee-5d5c83f393b0.jpg
#   inflating: images/9e3a96a1-e102-44fa-9aae-4bbb5d83a90e.jpg
#   inflating: images/9e40d0b5-a940-45d2-a666-f6fcb2c5f953.jpg
#   inflating: images/9e4c3e80-4a15-4eb6-a3bc-7c671bbf2754.jpg
#   inflating: images/9e4d1bbe-f92b-4e9b-a12b-e362703e351f.jpg
#   inflating: images/9e54480c-0970-434e-bd67-39459a641b2a.jpg
#   inflating: images/9e5714a0-3f58-4db9-aee9-ae29293582b1.jpg
#   inflating: images/9e5836ed-095a-4d62-a51f-cc89aaba3174.jpg
#   inflating: images/9e62b3e6-ae50-44fa-9bb4-3b2a07d53c60.jpg
#   inflating: images/9e63a516-c487-4038-87df-feb9652ac710.jpg
#   inflating: images/9e64f4d9-d9e9-4f43-87a3-7e7d514d129c.jpg
#   inflating: images/9e6a7ce8-fbb2-4772-8dd3-09909aab81c1.jpg
#   inflating: images/9e6aa6a3-de0c-4125-9e11-bfb7440df285.jpg
#   inflating: images/9e6f2983-7be0-40f9-9d9c-36668624604e.jpg
#   inflating: images/9e7610e1-35e0-4b02-94bb-8eb09833e5cf.jpg
#   inflating: images/9e7833c6-6b57-4f09-bcba-85b022876740.jpg
#   inflating: images/9e7b845f-8d4a-457a-8700-007e0dd7b21d.jpg
#   inflating: images/9e7de0d1-584f-41dd-a04a-96e5448d1b50.jpg
#   inflating: images/9e86a16f-468e-4abb-a89c-1a3b8fb6cccb.jpg
#   inflating: images/9e86ab7e-84de-475b-8b53-e2a3a413713d.jpg
#   inflating: images/9e8a8e05-68c9-4205-b4b1-13694b8644aa.jpg
#   inflating: images/9e98a923-9fa0-4bc7-ab1e-c5c0110c77da.jpg
#   inflating: images/9ea5c1d2-0c8b-4199-b3ef-7eb957502e3f.jpg
#   inflating: images/9eb77696-a159-4b58-92bf-91d42540856f.jpg
#   inflating: images/9eba5ccd-c08c-4121-b7d4-352a5cfb61d7.jpg
#   inflating: images/9ec20053-6546-4dfe-aa3c-393495e4abf8.jpg
#   inflating: images/9ec2341c-c4b5-42d9-84f2-eeb1e7e45782.jpg
#   inflating: images/9ec31a9e-0b0b-4c59-a95d-9cfd9b7eefa9.jpg
#   inflating: images/9ecd1d47-4b5a-406e-9855-291594b1b4db.jpg
#   inflating: images/9ece8f61-01c2-4ed8-8948-094d35d6b97c.jpg
#   inflating: images/9ed6b5a7-96a7-471a-a424-26213d93eb86.jpg
#   inflating: images/9edc11b8-9027-41e3-81c5-adac0b4a256c.jpg
#   inflating: images/9ee71248-2b15-4afc-8915-9bc33a64c858.jpg
#   inflating: images/9eed9802-b382-4ef3-93ea-d17ec1a94c19.jpg
#   inflating: images/9eef61be-26b8-4edd-8e76-bb6dec07ef38.jpg
#   inflating: images/9f1050bb-cd8e-46e9-9152-623338634667.jpg
#   inflating: images/9f12659a-a335-437e-bed2-6dfce6b7cf46.jpg
#   inflating: images/9f19a2bc-3353-4567-90f0-88e79bd1def2.jpg
#   inflating: images/9f214ce7-0b5f-4dd8-a584-c23ecf323ce1.jpg
#   inflating: images/9f253b1d-ee91-4c3d-967d-10719c97ac39.jpg
#   inflating: images/9f29949a-76e8-4ad5-a1ff-03ff2c9eb977.jpg
#   inflating: images/9f30cdb2-015b-45fd-80b3-c4f8568880dd.jpg
#   inflating: images/9f322097-80a8-42cd-afa6-79afe9866479.jpg
#   inflating: images/9f3a3250-839b-48ab-b7a7-e62ecfee0e31.jpg
#   inflating: images/9f3b0598-6c51-4fc8-bb88-899730f5302c.jpg
#   inflating: images/9f3d4dc5-68cc-48ec-ac79-6c027d478da3.jpg
#   inflating: images/9f4e729e-1be8-4924-bf3b-ebfd4db49bcd.jpg
#   inflating: images/9f508567-79c3-4a7c-8b3d-714ef290b7d8.jpg
#   inflating: images/9f58553b-e5bf-455a-b69e-a720d1c30c2c.jpg
#   inflating: images/9f65f710-196c-4d4c-ac4c-6d1b4c6559ec.jpg
#   inflating: images/9f68c5d6-4605-4586-beed-5fcb9b5ebedd.jpg
#   inflating: images/9f6f08d5-be99-49a7-9960-35651b18c28d.jpg
#   inflating: images/9f72a96a-e5ee-4d33-88d6-6cf19153c4ed.jpg
#   inflating: images/9f778087-7575-4e5d-9696-16d7c138f79d.jpg
#   inflating: images/9f7e380a-1458-407d-9e3c-2cb6dbe0b2e6.jpg
#   inflating: images/9f86b92f-f4ed-4c4f-805c-a7710d776962.jpg
#   inflating: images/9f874c87-e62a-4e50-a794-6f04cdaeab32.jpg
#   inflating: images/9f992ce6-bfe9-49ab-9092-72838d046669.jpg
#   inflating: images/9f9fcaac-1558-4d2e-b579-7eb564158e59.jpg
#   inflating: images/9fb09bac-1cb1-4815-b336-58c9df92e051.jpg
#   inflating: images/9fb23294-3930-4c2d-9e83-626a83034494.jpg
#   inflating: images/9fb366af-a4f4-45eb-9b36-ae9225351f0f.jpg
#   inflating: images/9fba6c36-5879-43c2-bbfb-8beabf3cab2a.jpg
#   inflating: images/9fbc7e73-ece0-4bf8-8b8b-64114b9dcb7f.jpg
#   inflating: images/9fc80be1-504a-4119-b401-c11d1c773ab9.jpg
#   inflating: images/9fd307ac-296b-406d-b7f4-61c5a96c9a55.jpg
#   inflating: images/9fd5eb41-2e25-4167-a368-c2d9fc9b2966.jpg
#   inflating: images/9fe049b4-bbee-46ac-9a79-c26b04ab0c61.jpg
#   inflating: images/9fe0899b-e99f-409f-9abd-5a0320e3573d.jpg
#   inflating: images/9fe39e42-4bd6-42c0-b5a5-da7d0c2434bc.jpg
#   inflating: images/9fe5420e-5cce-45d6-8980-fe405b862620.jpg
#   inflating: images/9fe559b3-03e7-4246-8390-1759e22cbe08.jpg
#   inflating: images/9fe59e10-431f-4e99-bcbd-51f28be575d7.jpg
#   inflating: images/9ff1024b-3a77-4ae3-b726-93f00782011d.jpg
#   inflating: images/9ffb0368-e981-4f18-9da2-a196b7ab6b02.jpg
#   inflating: images/a000341e-820d-488b-8abe-422338134fe6.jpg
#   inflating: images/a002b55a-31ab-4899-8d03-a8d2960708b9.jpg
#   inflating: images/a002b6a5-2b01-4732-9d95-da28378a54f6.jpg
#   inflating: images/a00de864-fb80-44ae-96fa-c7979f8846ef.jpg
#   inflating: images/a016ad2f-0fc3-4d93-82f7-6b5fbd62587d.jpg
#   inflating: images/a016ed0d-296a-4dde-8a19-475abf641cca.jpg
#   inflating: images/a0170a85-2a66-48b9-87af-91edf0017a04.jpg
#   inflating: images/a018de82-3e28-428b-bd62-85afa9a7539a.jpg
#   inflating: images/a01e3e86-a1ac-4555-8397-0b8f06e0c035.jpg
#   inflating: images/a01ecd83-21b1-459d-aaff-e33314c787dd.jpg
#   inflating: images/a02aea8f-1268-4226-90e7-3bd6046e7214.jpg
#   inflating: images/a02cb76f-5dce-4d01-b2d2-a6181f9c6379.jpg
#   inflating: images/a02fd90a-3b00-4cf7-a00b-78a88a37fb5a.jpg
#   inflating: images/a031a923-1424-4d87-b8ab-e3da31ea2caa.jpg
#   inflating: images/a033b6e9-d553-4e56-a5f7-92ef30347bbd.jpg
#   inflating: images/a03a5161-a5d3-42a3-b683-f39021cddd9f.jpg
#   inflating: images/a0479a08-d619-4312-b00f-5b567707e3ef.jpg
#   inflating: images/a04882b0-5498-4f3f-830c-3ddffbf3c518.jpg
#   inflating: images/a04f0669-b81d-462c-a570-671b6ab3b026.jpg
#   inflating: images/a05421a5-ac98-4abc-a45e-27e181dcf666.jpg
#   inflating: images/a0652ad9-a21a-4770-9eb9-8ef9c004dcb9.jpg
#   inflating: images/a069f2f4-13c0-4911-8a5f-b50bd4b12104.jpg
#   inflating: images/a06e6549-b990-4605-b987-363d1b231edc.jpg
#   inflating: images/a072a500-163f-4e4e-8db4-61adf3071fbd.jpg
#   inflating: images/a082ddfe-a6f4-4f87-964c-53d856fde9e2.jpg
#   inflating: images/a0867263-6be4-4079-8df5-af74619a6083.jpg
#   inflating: images/a0933675-3f4d-4760-8ccd-436555759b78.jpg
#   inflating: images/a095ab34-d82a-40cd-b256-8ce7639a8b77.jpg
#   inflating: images/a09d639b-66e3-48a1-bfd6-b9350c8bd4ec.jpg
#   inflating: images/a0a2445e-178e-4dca-b85a-5dc8d8b41390.jpg
#   inflating: images/a0a7fbcb-4431-4ddc-b27e-2e8b58aebf92.jpg
#   inflating: images/a0b1c8d0-f57f-4518-803d-1f8a2821b2ac.jpg
#   inflating: images/a0bf5a3f-03c3-4422-b71d-895664ace847.jpg
#   inflating: images/a0c011c9-97f2-42cc-b371-973601a28066.jpg
#   inflating: images/a0c35f6d-aeef-433f-ad73-9e78d66ad705.jpg
#   inflating: images/a0c42614-3657-4af6-bf50-08a0baa6a809.jpg
#   inflating: images/a0c44152-b772-44f9-aefc-366855f282a3.jpg
#   inflating: images/a0c4594f-7071-462e-98df-dc1cfaae7cd3.jpg
#   inflating: images/a0cfddec-293e-40f7-a4b0-fa993bf5c33a.jpg
#   inflating: images/a0d098eb-5794-4982-97bf-89b8fdb297c2.jpg
#   inflating: images/a0d43e69-166a-42b0-87f3-abafaa9ba95a.jpg
#   inflating: images/a0e20e6d-af44-405e-a8f3-5a230aa73058.jpg
#   inflating: images/a0e71001-2a4a-4d34-a8b8-3f863f008da0.jpg
#   inflating: images/a0eafa26-07e3-4799-910d-ea4c63a2fda8.jpg
#   inflating: images/a0f038e0-7a96-447e-a6a9-6b884efdb06d.jpg
#   inflating: images/a0f51400-fd17-4c89-bac9-4ff4924e19f8.jpg
#   inflating: images/a0fc0100-64f8-4880-8e57-470bc2966f98.jpg
#   inflating: images/a0fc40ce-8932-4e30-aff6-1d2c5d05687b.jpg
#   inflating: images/a10088a5-887f-447c-8088-e9b8d37716c2.jpg
#   inflating: images/a101dae5-e51f-4bdf-a9ba-78b6d2222422.jpg
#   inflating: images/a102e474-73a2-45b8-a8bb-d7df26c9adc0.jpg
#   inflating: images/a1053df8-7b33-4f2e-9792-fc37f0dd5981.jpg
#   inflating: images/a10676da-0807-4734-b010-64440eb13ee1.jpg
#   inflating: images/a1086adb-f9cb-4ccd-b942-ddb218e8454e.jpg
#   inflating: images/a1091163-6b74-4a32-9f9a-5d3e43039ecd.jpg
#   inflating: images/a1099f36-7c9d-4702-a9e1-137c1eecdba2.jpg
#   inflating: images/a11357fd-6fdc-4ad3-a376-d80762a10993.jpg
#   inflating: images/a1154e1d-c608-43cd-8c13-1fbd987d7e2e.jpg
#   inflating: images/a123fb77-d5e3-4211-b08c-34b7452d407a.jpg
#   inflating: images/a12434f3-99a1-4725-a7a4-3a6681729c1f.jpg
#   inflating: images/a125ea67-6824-4f36-b819-2509c2c09943.jpg
#   inflating: images/a127ee99-e3db-45f7-a6ce-0c7acbf20e7f.jpg
#   inflating: images/a128e5f2-5900-49cc-924d-21d96144832c.jpg
#   inflating: images/a12b3cd0-cf7d-4276-b8e2-a692605356d2.jpg
#   inflating: images/a1323dad-f094-486e-95e8-2e832d34d44d.jpg
#   inflating: images/a134a501-a7af-421f-9d3e-cc3e9f56634a.jpg
#   inflating: images/a13680c3-55fb-41ce-b4ad-7cdb3daf2b27.jpg
#   inflating: images/a13fa3d4-7cce-48e7-8c96-c88d6c416e27.jpg
#   inflating: images/a1402358-efcf-4511-be33-7a38ef878200.jpg
#   inflating: images/a146505d-6245-49ec-80b8-74bb880fbe3f.jpg
#   inflating: images/a148b7a5-b11a-4974-9adc-8aa4f68b23dc.jpg
#   inflating: images/a14db0f0-c7a8-4daa-9668-9aa7e8f30e16.jpg
#   inflating: images/a157a89f-6de3-4d33-81fa-bafd3e0b20dd.jpg
#   inflating: images/a15c6886-f9b2-490b-a626-cfe9c0e5f148.jpg
#   inflating: images/a161d51b-c8c5-4cd9-b0b3-f2df24d263fa.jpg
#   inflating: images/a167d01f-4308-4b00-943d-15108959713e.jpg
#   inflating: images/a169a496-c450-4495-87a8-63cdc2492b7a.jpg
#   inflating: images/a16a93e1-3efc-41ab-9e7f-e62f98ef729d.jpg
#   inflating: images/a170c3c4-c307-4fc4-94e6-3f4af8016e1f.jpg
#   inflating: images/a17dc7f2-e05e-4df4-a817-d5f309a7d1b3.jpg
#   inflating: images/a192735a-8a98-4b51-9f5c-49eb58d09ca6.jpg
#   inflating: images/a195327d-9964-493c-9b4f-7110e2bb6a31.jpg
#   inflating: images/a197b3fa-1b04-4205-98c6-0577bd09f769.jpg
#   inflating: images/a19848ef-0e67-4a2a-b0ca-056031812d47.jpg
#   inflating: images/a1a635e4-14b3-4513-b8f8-5f4598c9e98c.jpg
#   inflating: images/a1b10dcd-8d88-4a97-b9c3-67c9e737f4e2.jpg
#   inflating: images/a1c3a78e-478f-4db5-9302-28696d4f3e76.jpg
#   inflating: images/a1c51a99-8d78-4b8f-972a-55b4d46a407f.jpg
#   inflating: images/a1c8a56f-d3be-46eb-96b6-6bc1aaf8eb7b.jpg
#   inflating: images/a1ccc007-a046-4c4a-96ef-c17f94d7a2ef.jpg
#   inflating: images/a1d77567-6dcd-4991-993b-dff4833c7ac7.jpg
#   inflating: images/a1d8e5f5-2983-48c8-a737-a63043a094e8.jpg
#   inflating: images/a1db620d-5905-433a-9977-cb897c465449.jpg
#   inflating: images/a1dcc51d-0c24-4031-84c0-f88617a3df74.jpg
#   inflating: images/a1e2b9a9-1362-40b8-a844-3ccad3c11499.jpg
#   inflating: images/a1e534a3-4002-49a5-91ac-93223430bbf1.jpg
#   inflating: images/a1e608b1-b10f-47b7-bea9-d6dc938c5b20.jpg
#   inflating: images/a1f5ce1f-617b-4735-ac47-c9e2aa0b3c75.jpg
#   inflating: images/a1f72612-a495-433d-899f-c9eec21514cd.jpg
#   inflating: images/a1f762b3-1480-4703-a9f6-0722a0db9131.jpg
#   inflating: images/a1f92c9f-16cd-498d-80ab-582d7ed4c08b.jpg
#   inflating: images/a1fccf7a-a3d2-48c8-981f-28a3830aab74.jpg
#   inflating: images/a216fca9-d2a3-45a1-9329-510de0d20c22.jpg
#   inflating: images/a21701e3-7b11-4107-a095-a0512da4ea74.jpg
#   inflating: images/a21cadb6-55b2-4686-a828-bd38e76f3b3b.jpg
#   inflating: images/a222a551-9448-41c3-af66-d070b2ee5926.jpg
#   inflating: images/a225bd59-28de-458f-8175-dddb1ca103fb.jpg
#   inflating: images/a2287520-9f80-4a66-b37f-a2bc9d091609.jpg
#   inflating: images/a228807e-661c-4bcd-9b4e-0136d9153516.jpg
#   inflating: images/a22b8157-0906-4e6b-856a-f5c560e6acd6.jpg
#   inflating: images/a22ede43-8927-41c8-968f-c305c3c1290a.jpg
#   inflating: images/a23295d9-2811-4291-a4f8-90c5cbb80341.jpg
#   inflating: images/a23e58f0-bc5f-4bef-920f-8b0ee006fa0b.jpg
#   inflating: images/a24480cd-e2d6-45d6-8bd1-c1d0864778d5.jpg
#   inflating: images/a2469eb1-552e-44b3-b397-08a1fcf80b42.jpg
#   inflating: images/a246e787-e53e-4040-9bf3-9483df6aa719.jpg
#   inflating: images/a255b767-7583-40af-bde4-0c2a7656a592.jpg
#   inflating: images/a2577576-690d-4d1b-be14-f4ed0838eb9d.jpg
#   inflating: images/a257df7e-802b-4016-b3e2-e1a59a3b0833.jpg
#   inflating: images/a259d092-b751-4de3-9a8d-c10fb06efea8.jpg
#   inflating: images/a25d6a3a-7cf4-41ea-9138-e1c1871eb7cd.jpg
#   inflating: images/a2627d8f-7841-488b-b509-bbfc36914605.jpg
#   inflating: images/a26413ea-2412-402f-a593-538e1309fbd1.jpg
#   inflating: images/a265d582-29a9-4bd1-954e-a1568c0512c4.jpg
#   inflating: images/a26f42ed-3583-42b9-a2b1-548936e124b3.jpg
#   inflating: images/a271687a-e212-43a4-a27b-5332d28d9bf2.jpg
#   inflating: images/a28d32d8-437e-497f-bedc-7dd367e7bbcb.jpg
#   inflating: images/a29314c6-dbb5-4116-99b2-4b3dab972c5d.jpg
#   inflating: images/a2959320-eb29-4a68-98f3-a584fc462234.jpg
#   inflating: images/a2983b9d-7c13-4690-ae52-dda775756e5d.jpg
#   inflating: images/a2a283b3-d9bb-46b7-b696-7617a9cdd6ba.jpg
#   inflating: images/a2a63328-54cb-480a-aafc-8c17e9cb8a39.jpg
#   inflating: images/a2a814c7-b017-4161-98d1-31017e1f5277.jpg
#   inflating: images/a2a884c4-abe3-4fcb-ae67-80e4d2baa4ef.jpg
#   inflating: images/a2a99b57-5168-4ee3-942f-7492b8fa3d18.jpg
#   inflating: images/a2ab6536-dbf8-4d3c-8eb8-52d88f697f0f.jpg
#   inflating: images/a2b2443c-5ac6-4078-bbf6-5c351c776356.jpg
#   inflating: images/a2b8d835-a45e-4e00-8be2-9a2cdf7f7b92.jpg
#   inflating: images/a2bac5d3-a1ad-4533-b5d5-38555f417b28.jpg
#   inflating: images/a2bc1713-550d-4b29-b91c-03aac163d6a9.jpg
#   inflating: images/a2beda01-9476-4cc4-aa22-a0ae6fb76ddf.jpg
#   inflating: images/a2c3d36f-f509-478c-98c9-7b122beaf56b.jpg
#   inflating: images/a2d5b322-7818-444c-83ae-9b03861cf8aa.jpg
#   inflating: images/a2d6f371-349f-4588-8d49-502be0a23576.jpg
#   inflating: images/a2d7826c-5bb1-4a93-9b4f-a34540911220.jpg
#   inflating: images/a2d958d1-73f7-4626-a041-3b6af1df2836.jpg
#   inflating: images/a2e0282c-a299-4063-a59b-4a4f9dad8b30.jpg
#   inflating: images/a2e0cd37-6b00-4506-8f8e-eafc3ad903fa.jpg
#   inflating: images/a2e4f450-607e-4074-9a24-422ce99bd01d.jpg
#   inflating: images/a2e579df-3329-4812-a8e3-811549f59b9d.jpg
#   inflating: images/a2e6bf34-903f-4b1c-bcb6-84590e7742d1.jpg
#   inflating: images/a2e91b7a-e442-4bff-ae3a-08e5790064ff.jpg
#   inflating: images/a2ec5361-6781-4a3b-b9f3-2a97da279b3d.jpg
#   inflating: images/a2ee12b4-17e8-49b4-8640-1dc68b7f6e5f.jpg
#   inflating: images/a2ef0f02-f152-4f5d-87e4-2654644ec78b.jpg
#   inflating: images/a2ef25f7-f445-487d-8f29-e964b620d5c5.jpg
#   inflating: images/a2f67c35-2198-47d5-be23-2cd683275d4f.jpg
#   inflating: images/a2f97e3c-bb52-4164-afd1-0142d26ca652.jpg
#   inflating: images/a2fded0f-57d5-4e9c-9504-308aca03bcc5.jpg
#   inflating: images/a30cf820-9f2d-4a58-93cb-6dfff737de53.jpg
#   inflating: images/a30d90ae-bf10-4b1d-8ae3-bfd2271a730c.jpg
#   inflating: images/a30e53ec-6eb4-42a2-adfa-e1f2eee6b40d.jpg
#   inflating: images/a30ee4eb-945f-4ac1-a46c-205b8978a8c2.jpg
#   inflating: images/a30faebd-ffec-47e3-bb8e-babb8ddc6e93.jpg
#   inflating: images/a313922a-bed6-4ea0-b5d8-5284ba858661.jpg
#   inflating: images/a319d675-4e20-48e7-a656-d6686a641a2f.jpg
#   inflating: images/a31e75f7-4f3c-4af5-8f59-05245a74a8d4.jpg
#   inflating: images/a3347ec9-9d0f-467b-9324-81af9eb4dd73.jpg
#   inflating: images/a3376f8a-74e5-4d97-84ef-4d2ccefc7fbc.jpg
#   inflating: images/a33bb3b5-40c3-4e28-85a7-945dba553847.jpg
#   inflating: images/a33f628c-06c6-4bcb-ad13-ef18e2d6155b.jpg
#   inflating: images/a341c744-cb4f-4676-8c27-7e95f4770f1f.jpg
#   inflating: images/a345328b-9cfc-4d80-a5b7-7a01ef1b6f02.jpg
#   inflating: images/a34ffb86-87b1-48b6-9a43-f651e3f892d0.jpg
#   inflating: images/a35d1c03-a51c-42ef-94eb-c7562389e92d.jpg
#   inflating: images/a36118b4-05bf-437b-a7f9-231a89c3038c.jpg
#   inflating: images/a3619cda-a5a5-4bc2-8ae7-9cf5acdab680.jpg
#   inflating: images/a3634c89-4570-4774-b939-0c62654fa7d8.jpg
#   inflating: images/a3636d46-2097-4a32-9d47-be83b87a5942.jpg
#   inflating: images/a363aec3-4c48-4c5a-96f2-39145cc4727d.jpg
#   inflating: images/a369130e-cc10-4744-af23-4c620bc9f6ab.jpg
#   inflating: images/a37019e4-0267-41e4-8758-e8c4689323df.jpg
#   inflating: images/a370d481-0e0b-4f5d-a543-2b70db934af5.jpg
#   inflating: images/a38423b3-8747-4866-9b87-8a478b237c95.jpg
#   inflating: images/a3849aac-3646-4aef-999b-bdaf051ad7a2.jpg
#   inflating: images/a389ad89-676c-41a5-b765-32ef3e8fccf4.jpg
#   inflating: images/a39baa06-3f68-4885-bea4-77d8a4bb1256.jpg
#   inflating: images/a3a12b64-8e72-4d73-a9a1-f8897c37c9b8.jpg
#   inflating: images/a3a2e5d4-747a-4ae1-a185-8e8a4a9d1a41.jpg
#   inflating: images/a3a7c432-3d24-4b1f-80ca-d534a1e932ae.jpg
#   inflating: images/a3a7f190-1021-4d1c-a54a-f34e35042ab2.jpg
#   inflating: images/a3a9c3f2-75e4-4801-a8f4-4b6ce1d579f6.jpg
#   inflating: images/a3b079b1-db49-4737-8239-5b79b226ecb0.jpg
#   inflating: images/a3b66671-872b-4cf8-941a-61b795a1d476.jpg
#   inflating: images/a3b948bd-5467-4df8-9654-2050b68f41b7.jpg
#   inflating: images/a3c35681-10b9-4d1d-9aef-40ff6c061ac6.jpg
#   inflating: images/a3c79a4e-8ccd-4b55-b828-6a90a9e2078e.jpg
#   inflating: images/a3cbdba4-7988-4d83-9f7b-3b5c454da73a.jpg
#   inflating: images/a3cda095-6e46-443b-be2a-e9b1215700bf.jpg
#   inflating: images/a3d084c8-be7b-4e5f-aac3-56fba7ac96bc.jpg
#   inflating: images/a3d0f669-c4e3-447c-8abb-1a53e1e4824c.jpg
#   inflating: images/a3db512e-0b40-4269-9473-32d69706c219.jpg
#   inflating: images/a3e9bad3-94e1-4536-a114-705aee0b3645.jpg
#   inflating: images/a3eb4f9e-d56f-4422-b6d2-cf8fda620d2c.jpg
#   inflating: images/a3ec9bb8-cbc7-4780-b252-c01f154dd8a4.jpg
#   inflating: images/a3f47bc9-9ed7-4d3e-97d0-d95e3a5c05b2.jpg
#   inflating: images/a3f66bf8-33d9-4be3-84ab-8bec8ed763fa.jpg
#   inflating: images/a3fed8e3-16af-4edc-939f-d4ee55aeab62.jpg
#   inflating: images/a4005f70-48a7-43bb-a2dd-ce188d29a5fd.jpg
#   inflating: images/a401ea83-d3e5-41ee-9242-80c3740b1e7e.jpg
#   inflating: images/a404eb30-c3b5-4891-ad55-d7e6e57690c6.jpg
#   inflating: images/a4076f14-4810-4389-ba6c-2dc1d3ca1252.jpg
#   inflating: images/a40dd0dd-c862-4df5-be74-1e114d9c43db.jpg
#   inflating: images/a40e9e82-e168-4a78-9c7d-ea1ee28d1fd4.jpg
#   inflating: images/a412551f-6d92-41c4-8591-2d40fec1bfdc.jpg
#   inflating: images/a41cb5c8-74eb-42bc-9111-deb15ec30c89.jpg
#   inflating: images/a42e8d72-646d-4f17-8232-235b4455b4c7.jpg
#   inflating: images/a43216ab-ac44-4897-b940-c5396b5e3834.jpg
#   inflating: images/a4398c52-3a47-4b32-ab0e-02427b39a4b1.jpg
#   inflating: images/a43b3685-2bfc-4ede-aaaa-a38e888397a5.jpg
#   inflating: images/a43d6692-dcc4-4c18-b005-c8d8f694f273.jpg
#   inflating: images/a43f3e2d-7f6a-4e23-b981-06802581af02.jpg
#   inflating: images/a4405ed6-e90e-48d3-b23f-ed2f79968617.jpg
#   inflating: images/a442007b-db4b-41ef-8b28-65c91be1dd72.jpg
#   inflating: images/a4430413-f839-4b60-881d-44fe36f7e4d4.jpg
#   inflating: images/a446852c-7867-4776-babb-03b204638f38.jpg
#   inflating: images/a446f2c2-905a-419c-97fe-09a0290ecbdc.jpg
#   inflating: images/a449fb03-e1f8-4862-b3bb-b848af211310.jpg
#   inflating: images/a459bcaf-8e63-4795-9fd5-88eeced57d6a.jpg
#   inflating: images/a459e0a8-6858-4852-9fd9-ec48384e346f.jpg
#   inflating: images/a45ab941-b46d-4074-a736-a9f5a5b18a91.jpg
#   inflating: images/a46a81a8-3ecf-4aea-856b-744a8033df0d.jpg
#   inflating: images/a46cb4e6-81e7-4d2d-a12b-f2770765091e.jpg
#   inflating: images/a46dd8b3-98bb-49be-8cb3-8eae94d30443.jpg
#   inflating: images/a4740dcb-187c-4df5-bc4e-199ea9bdbfe2.jpg
#   inflating: images/a4760953-d5e0-4625-ac08-ce3981fcc326.jpg
#   inflating: images/a47662d5-b7d6-45b8-ba5d-ab34c5635108.jpg
#   inflating: images/a477611e-063c-4f89-b380-13ec20a6305c.jpg
#   inflating: images/a47ae6eb-99cb-4990-975d-50dca45a1271.jpg
#   inflating: images/a47c9a3b-a40f-46b0-92b0-6d6dd2a4e308.jpg
#   inflating: images/a48134b7-8d4e-405f-864d-cc99f5a29de7.jpg
#   inflating: images/a4870e17-cf3c-4fa8-8519-19877aa6eaa0.jpg
#   inflating: images/a489c817-6985-48e9-8cdb-03a4079ae68a.jpg
#   inflating: images/a48b2c92-f935-4b06-86f3-8e07a66f93ec.jpg
#   inflating: images/a496395c-6a76-47d5-845e-64b795bcd6a3.jpg
#   inflating: images/a49a6b81-42ed-4b77-94a7-184d56bd9d83.jpg
#   inflating: images/a49c7e2e-5511-4314-9f46-155cf9e4236a.jpg
#   inflating: images/a49e68d7-3683-441d-81e7-5d79c43012f5.jpg
#   inflating: images/a4a2a635-74bd-4ee8-9b8c-a555196762fd.jpg
#   inflating: images/a4a72463-b526-4798-9583-e1c0303ea575.jpg
#   inflating: images/a4b44d82-01b9-4c13-a92d-87b3ff9407d9.jpg
#   inflating: images/a4c11910-09c8-484e-8280-4de40bc975bf.jpg
#   inflating: images/a4c7abd4-5fe7-464a-bb02-e5b72d0b69cf.jpg
#   inflating: images/a4c888bd-e418-4e94-a289-16ffa59a148f.jpg
#   inflating: images/a4cb39c9-e093-4c28-a938-3ee119c0224f.jpg
#   inflating: images/a4cee528-5fa2-4546-bd41-25d609baa18d.jpg
#   inflating: images/a4d2cf68-cde0-447a-ad54-098420a08525.jpg
#   inflating: images/a4d5fa40-415a-4427-8515-873dc6debb7c.jpg
#   inflating: images/a4d93870-2298-4b1e-bc54-c34863acf60d.jpg
#   inflating: images/a4e970ec-8b91-4c67-8cd3-d4253f6b7d0f.jpg
#   inflating: images/a4ec3df0-4482-4601-a309-2729923613e1.jpg
#   inflating: images/a4ec61c7-13d8-47b9-b0ef-b9a3ec4d94cb.jpg
#   inflating: images/a4f3d280-fbd7-4cbc-9069-0a691f54a6c6.jpg
#   inflating: images/a4f63af2-9b1e-4ecd-bda7-0dc8484eb5d1.jpg
#   inflating: images/a5033f5d-f3de-4cfa-93e2-c72f1c7fa604.jpg
#   inflating: images/a50a710b-19d6-499a-a618-5a69d81b8bfc.jpg
#   inflating: images/a50e89cb-aa32-488c-a8c5-a742e47a3526.jpg
#   inflating: images/a50eb603-51ba-482b-b9ac-f07132951195.jpg
#   inflating: images/a50f1709-17b8-47ed-ae5f-89b949a03688.jpg
#   inflating: images/a5125645-3c54-4c36-a48a-18dbe8e15996.jpg
#   inflating: images/a512c09e-fe8f-4ece-9fee-ab45e6e1762b.jpg
#   inflating: images/a513fc57-9efb-429a-a5bf-b01abe8a0d31.jpg
#   inflating: images/a51d56c4-3874-47d5-8abc-74277095347f.jpg
#   inflating: images/a52b4561-8d25-46af-aeb9-959210ea9834.jpg
#   inflating: images/a53096bb-0426-428e-8237-4bba661b2054.jpg
#   inflating: images/a53771a7-2011-4af0-a1cd-b56b47253211.jpg
#   inflating: images/a53ad6f5-227b-4524-9a7c-f3f5fceb520f.jpg
#   inflating: images/a54a5eb1-250d-4c28-a16e-38bf5dad5d44.jpg
#   inflating: images/a54d47b9-1ba6-471d-a622-b5b7d8f8b03a.jpg
#   inflating: images/a554364f-f66e-48a2-a7b2-a78c84bdf485.jpg
#   inflating: images/a55e6108-2414-4800-a5e4-bbf479b808e6.jpg
#   inflating: images/a55e7ce5-398d-47d3-9b48-da0cbfa4a83a.jpg
#   inflating: images/a5645804-63e8-4053-997b-5476f3cc66fe.jpg
#   inflating: images/a56462d9-7c1a-4b7b-9d8f-700d505449ee.jpg
#   inflating: images/a56628c0-db32-4738-899c-14e8fa4ebeb3.jpg
#   inflating: images/a56ae844-8b48-4c68-8c19-c866f0bc3d83.jpg
#   inflating: images/a574fbbc-0c65-464c-8dbf-b146cafc9e81.jpg
#   inflating: images/a579bb39-700b-4354-a9e6-630af1ac9ffd.jpg
#   inflating: images/a57aa5bc-3aa4-4ce9-8ebf-3caff6a31e2a.jpg
#   inflating: images/a57e7c2e-5652-4a81-b08e-fb3d273d190a.jpg
#   inflating: images/a57f95c8-0475-4309-a0e1-0b52225ee146.jpg
#   inflating: images/a57fb33d-9d03-423f-9d52-de16c7163a16.jpg
#   inflating: images/a58a3354-1f62-4d22-9232-fac5ad85c2e3.jpg
#   inflating: images/a599b8aa-ef4c-4875-a6c2-44f054abfe3d.jpg
#   inflating: images/a599bcfc-0cde-4acf-b035-b64b5f8a4f5f.jpg
#   inflating: images/a59d4291-d2a1-4604-95f8-5dc7cb65ddcd.jpg
#   inflating: images/a5a62731-3d8e-4dd3-a924-9fa9cf7c6e8e.jpg
#   inflating: images/a5a7e3db-1d88-475e-a837-0355b000ebef.jpg
#   inflating: images/a5a8a847-4563-4118-8cac-c9aef44b7040.jpg
#   inflating: images/a5ae0c1e-9e3b-4950-8eb8-57582fd5961e.jpg
#   inflating: images/a5aeb9c3-48f5-4172-83ae-f91374c10beb.jpg
#   inflating: images/a5c1d61b-7fdb-4f72-97e6-5334378e6226.jpg
#   inflating: images/a5c94dea-715a-40bc-89f4-c057acd4876c.jpg
#   inflating: images/a5d12258-50d3-478e-876a-2e56f306458f.jpg
#   inflating: images/a5e506df-69df-4dd7-92b6-e1cd71a3066e.jpg
#   inflating: images/a5e7fb4b-5194-423e-8912-00df17b42a61.jpg
#   inflating: images/a5ee0055-f1a5-44a3-ade6-54041393c0aa.jpg
#   inflating: images/a5f36ad7-5689-4eb9-8e81-613c64f5c32e.jpg
#   inflating: images/a5f69a02-3a51-457a-b043-6284ea1fd48e.jpg
#   inflating: images/a5fdda48-568c-4417-afca-fab62c27cd98.jpg
#   inflating: images/a5fe3a41-d562-4ef0-9a68-81ebe0c0e356.jpg
#   inflating: images/a603541d-19d6-4718-9b62-e1d206ced460.jpg
#   inflating: images/a606d9f9-840a-4937-85f6-3437ca0091d2.jpg
#   inflating: images/a614d0a0-aeca-4066-b9d6-a41a182bb90d.jpg
#   inflating: images/a623a790-08c1-4e32-a9ab-adc1df44fa87.jpg
#   inflating: images/a63874db-0ebc-4194-be06-b6538a678faf.jpg
#   inflating: images/a6488a89-e860-45e4-8fe1-fbca2ca51d6c.jpg
#   inflating: images/a648b18c-25d0-4905-b54a-1bd0e99b4911.jpg
#   inflating: images/a64ec53a-2745-4ff1-879b-cd523584716d.jpg
#   inflating: images/a6527d7c-4152-419e-9a9b-2e88276b985c.jpg
#   inflating: images/a6563efe-53b2-43fc-b35d-a94901dcd1e5.jpg
#   inflating: images/a65b8777-03e3-4b97-ad78-74bc82e75fad.jpg
#   inflating: images/a661350f-f918-4f0a-8da5-900290dc6e57.jpg
#   inflating: images/a66767a2-40f1-4d0a-9cee-a412ac056d83.jpg
#   inflating: images/a66a0679-a65f-4596-aed3-c331bfd65d3a.jpg
#   inflating: images/a66a748c-3cf4-4273-acaf-b01344ee5f33.jpg
#   inflating: images/a67a57c9-2c78-4c40-9184-45a535c20235.jpg
#   inflating: images/a6842f51-d05a-4790-b44a-c7ac8d45e99f.jpg
#   inflating: images/a68feea7-12ff-44c5-88e5-113fd3a64b24.jpg
#   inflating: images/a6911196-61ef-4f0a-971f-6b59ccbc16d6.jpg
#   inflating: images/a694c374-4411-479f-bb72-434bda7dd4c1.jpg
#   inflating: images/a695deaf-3dc4-42be-9d00-71272fd8bee8.jpg
#   inflating: images/a696098c-8fbc-4faa-b777-0f8397eeb503.jpg
#   inflating: images/a69b4769-4c39-4f22-9215-3935cb2d76dc.jpg
#   inflating: images/a69e5d6c-6b8d-4408-85de-092a6431f980.jpg
#   inflating: images/a69f2d03-b16d-4099-a1e7-81b2177082a1.jpg
#   inflating: images/a69f3d87-1660-45ba-9211-7e9ad429d5ab.jpg
#   inflating: images/a6a5aa5a-ac6d-4720-94ac-bae38e18043e.jpg
#   inflating: images/a6bd13c1-ad51-4a68-b959-ec27405caf1c.jpg
#   inflating: images/a6c8f5ba-a92e-485c-b391-1005b1d2917b.jpg
#   inflating: images/a6ce27f3-f72c-407d-b8ea-57b7a5da9bdb.jpg
#   inflating: images/a6d68b52-1da0-49be-a625-e144c526b70b.jpg
#   inflating: images/a6daaed6-a41b-4857-b35c-ecaf9d579877.jpg
#   inflating: images/a6e5be1c-835d-4853-b448-6f8044b06921.jpg
#   inflating: images/a6e7fc54-96e7-49f0-b004-349bdf714cc7.jpg
#   inflating: images/a6ef9eef-7729-4570-9f71-d4027739c44f.jpg
#   inflating: images/a6f65304-bf0b-47d3-9763-606a56366cfa.jpg
#   inflating: images/a6f8d9bb-ec56-46a1-a709-67d84a935802.jpg
#   inflating: images/a7015e9e-eefe-460f-ba20-37b181a445c5.jpg
#   inflating: images/a70712da-bd64-430f-8ef9-062cb6d05948.jpg
#   inflating: images/a70eedde-0ef7-4f74-87d0-fd7d91b1fde2.jpg
#   inflating: images/a7124b75-0412-4939-a021-344a8bd87681.jpg
#   inflating: images/a71b134a-2791-41b1-bd8a-138d1939c30a.jpg
#   inflating: images/a7216313-7afe-452e-abc7-89b6aa1f13cb.jpg
#   inflating: images/a7286d51-7297-4c62-ac29-124f9c7ad4ac.jpg
#   inflating: images/a72d6bb7-a1a3-4baa-953e-f7fb239f9852.jpg
#   inflating: images/a7308a9a-1094-44eb-bba7-cc1a65d55d49.jpg
#   inflating: images/a73467c8-f055-4891-b436-dbf9a0331786.jpg
#   inflating: images/a73dbfd6-51c2-485e-816b-e9aafabef638.jpg
#   inflating: images/a73ed197-1b36-483a-9951-0830bc5ae5dc.jpg
#   inflating: images/a741a897-1f16-4eb1-9675-ba8da46a3d12.jpg
#   inflating: images/a7423681-e6cf-45d0-8a5a-e01ea75d2c21.jpg
#   inflating: images/a7485d0b-f8a9-4065-81e4-7f23f9578269.jpg
#   inflating: images/a7495023-718c-4972-84ea-d3591975f3c7.jpg
#   inflating: images/a74ad048-d38b-48ce-8e20-3909f055aa7e.jpg
#   inflating: images/a74d948b-004d-44b3-a4d3-e47f0eac42b4.jpg
#   inflating: images/a7501394-b171-452c-929d-e98f28d0d082.jpg
#   inflating: images/a7585332-553a-480e-8bd8-c89dc4992c63.jpg
#   inflating: images/a76252eb-4ab2-4f6d-8b43-da9e4d85d776.jpg
#   inflating: images/a7655c03-a4e7-40da-bb04-0eef99c96b38.jpg
#   inflating: images/a776ab18-e3c8-4d39-99ec-7b9f86bc5236.jpg
#   inflating: images/a77d4d98-a8f9-484d-8ace-9f1c86b84936.jpg
#   inflating: images/a78936c4-ca32-4689-8700-f2314ba5d37c.jpg
#   inflating: images/a78d26a6-2019-4c5d-81ed-6f5a9c37b932.jpg
#   inflating: images/a7940325-573c-4823-bc7e-3af62a90e800.jpg
#   inflating: images/a7945771-5a9f-4b08-80d1-d8ee62a818c1.jpg
#   inflating: images/a7947fe9-9f5c-44e2-be4e-491854949e5e.jpg
#   inflating: images/a79490ed-f1f8-4d47-b335-06d35828e53c.jpg
#   inflating: images/a7968f52-1564-435b-bfd8-40b550529e21.jpg
#   inflating: images/a79c06e5-1f57-4dc7-a677-adbb2c728474.jpg
#   inflating: images/a7ae57ce-1a5a-4e5e-87d9-cbfcdfc13d8f.jpg
#   inflating: images/a7b7d54d-71b2-409f-94ef-21ac868c424e.jpg
#   inflating: images/a7b88fd9-f163-4dbe-96f9-6c5fd3c92d58.jpg
#   inflating: images/a7b963d0-4a3c-4cce-b6b1-da4d65b10f7d.jpg
#   inflating: images/a7ba2922-bfb2-45b8-ada6-94e8c3368fa9.jpg
#   inflating: images/a7ba3fd4-2afa-450a-bc3a-268b7da0230b.jpg
#   inflating: images/a7bad982-841c-40b3-932e-cd274deb8ead.jpg
#   inflating: images/a7bb9f87-306c-42b3-911e-a9a259aeb20f.jpg
#   inflating: images/a7cb956e-264b-42ab-817b-09eb53820fe6.jpg
#   inflating: images/a7d25f29-b45a-4b7a-994f-3b0838fc8117.jpg
#   inflating: images/a7d32e34-f50e-4cfd-9c9d-4940d3a28999.jpg
#   inflating: images/a7d3c15c-5aac-4f45-87df-a7267b9ffdf6.jpg
#   inflating: images/a7d504de-5ddd-4cca-91b1-1d05b62cdb30.jpg
#   inflating: images/a7d5a995-2667-4cd2-961f-d0618d0b9cee.jpg
#   inflating: images/a7e252f6-de5a-4e20-b5fe-9d60bc9f6626.jpg
#   inflating: images/a7e5f358-da13-43a5-a254-67eb738423da.jpg
#   inflating: images/a7e7cdba-7134-40db-bfe2-06bc079ef678.jpg
#   inflating: images/a7ec03a1-e0c7-40a8-ad94-4844bf58033b.jpg
#   inflating: images/a7eecdf0-1618-408d-b08f-ee3075870689.jpg
#   inflating: images/a7fcceb7-acc3-4eb4-98cf-71eaa574968d.jpg
#   inflating: images/a8028a1b-c851-4941-be52-45667602037f.jpg
#   inflating: images/a80e5811-8720-4f79-a716-6bfa502cb91e.jpg
#   inflating: images/a80f320a-9e5c-4e41-8b5c-3f5ff0296660.jpg
#   inflating: images/a813521c-9b35-41a5-80d0-cc9b6e342482.jpg
#   inflating: images/a8141cb2-09cd-4106-8bea-9243aad715f1.jpg
#   inflating: images/a8174b19-9622-487f-9a1d-7e5ad664baab.jpg
#   inflating: images/a81b29f7-952e-4e9b-b1f6-f42c6637d157.jpg
#   inflating: images/a82142d9-7d40-4755-94c6-773d75d3e49b.jpg
#   inflating: images/a82d3113-ddd9-4635-976a-2a724f3efc01.jpg
#   inflating: images/a8380965-60e1-4347-bc97-6a03cf679e90.jpg
#   inflating: images/a83c614c-8769-4d8d-babc-ebce6cf50dd0.jpg
#   inflating: images/a83cd73b-8c34-4dbf-bc61-7136198ab6cf.jpg
#   inflating: images/a83f3afb-a65a-4009-88e4-21520c04f5c0.jpg
#   inflating: images/a84393a7-74d0-439f-82a9-74a7cc9f13a3.jpg
#   inflating: images/a848a904-20c7-4512-96df-af41691f02b4.jpg
#   inflating: images/a852e202-eccf-41d4-a068-e2522caab3b8.jpg
#   inflating: images/a857899d-498f-4eb6-81e0-bb2985abf473.jpg
#   inflating: images/a85f5587-1c0f-4147-96f3-ff4cbf250978.jpg
#   inflating: images/a85fbea8-8c13-4fc5-9796-0eea4c890d7b.jpg
#   inflating: images/a8604c85-c1bf-4de8-96e2-0eea995431c2.jpg
#   inflating: images/a8605546-ea2e-4c2e-b55a-ba523a22fb5a.jpg
#   inflating: images/a863549c-415a-4bfc-a045-dba3fb9e9930.jpg
#   inflating: images/a8665218-253a-4173-ab9e-cec11a345c3f.jpg
#   inflating: images/a8669f63-77cd-4336-bef5-c3faed789b9d.jpg
#   inflating: images/a870ff5d-2e8d-4264-a00d-2cf431117f41.jpg
#   inflating: images/a871557e-4952-4f47-9a78-53fc442358d3.jpg
#   inflating: images/a8734030-4c68-4ea9-831b-9f68425d3a7d.jpg
#   inflating: images/a8766384-1983-4f3b-87f7-64a7ba3f23bb.jpg
#   inflating: images/a87844ee-ee91-4d3f-886f-f7227d61989f.jpg
#   inflating: images/a88640cb-23cb-4b95-ae8a-edb38ea1eca2.jpg
#   inflating: images/a894deda-04fa-4b04-a3f1-35116ffc0b97.jpg
#   inflating: images/a8979189-fd03-48cc-9954-0624863ecf32.jpg
#   inflating: images/a8a3b300-9fcd-41ce-9ca8-e33c9ff824d5.jpg
#   inflating: images/a8aab092-25c9-4ac3-941d-0fdc2523a16a.jpg
#   inflating: images/a8af8c20-4c4c-473a-96ac-a021dbfce78e.jpg
#   inflating: images/a8b08fa2-af84-4ec1-b74d-3269255678a5.jpg
#   inflating: images/a8b1e4eb-bfbb-4e63-88a3-8d1eb2212aae.jpg
#   inflating: images/a8b7deee-879f-4a58-8e2a-6942c44af71e.jpg
#   inflating: images/a8b94ef5-c763-455a-a459-68290fafa369.jpg
#   inflating: images/a8bf2af0-06b9-46e0-94ab-feb7f70dab36.jpg
#   inflating: images/a8c009d1-5006-4891-bc01-e4ec1d0d4297.jpg
#   inflating: images/a8c05cf1-60c4-495d-a392-565bb2876755.jpg
#   inflating: images/a8c05d57-00e4-4604-8e10-0616dd8f7536.jpg
#   inflating: images/a8d7e204-2f93-45bb-9a70-386f5b2c70ca.jpg
#   inflating: images/a8ddf4b9-3b81-4dfb-b4f8-4487f2d4c8ac.jpg
#   inflating: images/a8e370e2-fdf4-4b81-acd0-f30e975c0479.jpg
#   inflating: images/a8e8a7c4-b5e1-47a3-95ac-62b39b898eda.jpg
#   inflating: images/a8f4aa1c-f83e-4f64-87fb-bf588b5c9196.jpg
#   inflating: images/a8fd0e0a-4079-419e-8de5-c5973bdb3db7.jpg
#   inflating: images/a8ff3337-0595-4a57-9d0a-6d5712b6c6ef.jpg
#   inflating: images/a9033ba5-f4e1-4033-bc3d-a36d27c39d3f.jpg
#   inflating: images/a90df44f-c4bb-498c-827f-3db2740d5613.jpg
#   inflating: images/a91173e2-e9f0-41af-bd7a-19a09c42ce42.jpg
#   inflating: images/a9159565-20fe-4425-be92-9edb50d4745b.jpg
#   inflating: images/a91938a0-aa6a-4cc2-befe-3bbae2252ccb.jpg
#   inflating: images/a91fb248-2b41-4af0-97fe-067988ec5016.jpg
#   inflating: images/a92a9e12-fb74-46df-a1a7-a74c52099004.jpg
#   inflating: images/a92b3930-1276-4e94-b782-121dfbf3f030.jpg
#   inflating: images/a92bed43-3974-409e-8dd5-eb2ca6b89a92.jpg
#   inflating: images/a930b903-ff08-40be-ba25-dbbf4e822981.jpg
#   inflating: images/a932ccfd-2b89-4d05-8d98-26ca0eff4a53.jpg
#   inflating: images/a9348e6e-41d5-4053-bb3e-aa3dc3169340.jpg
#   inflating: images/a93896dc-c035-48aa-9280-ab2a12e8ce60.jpg
#   inflating: images/a93a1d78-52c5-4f58-ac5e-a974e41d9580.jpg
#   inflating: images/a93fbd69-90a6-4269-8828-97ade8bc138a.jpg
#   inflating: images/a9419db5-44b9-4c6e-8bcb-002dd44cfc87.jpg
#   inflating: images/a942edb2-497d-4e91-8a6b-8347fd15b2da.jpg
#   inflating: images/a94da2b8-36fd-40ee-85d7-24b4b004d3aa.jpg
#   inflating: images/a951f7b6-4363-471e-8bf3-65357697b7b8.jpg
#   inflating: images/a957ffa1-9de6-4df9-b1a4-aae12ff6fd87.jpg
#   inflating: images/a95bc25b-5fac-4c4e-9917-4921b2b762cf.jpg
#   inflating: images/a95c471a-6baa-460a-98a4-7c20e40b87a1.jpg
#   inflating: images/a960e684-8365-4d30-85dc-e0b7bc6a1b35.jpg
#   inflating: images/a96239b1-15ae-4984-adc6-4c3062bec87b.jpg
#   inflating: images/a962e26f-86db-4f56-b7bc-6a34aa26c32d.jpg
#   inflating: images/a968cbc0-02d0-4fa4-acde-1841d932f791.jpg
#   inflating: images/a9713e13-5aef-4085-b7b1-89f536422ece.jpg
#   inflating: images/a97c6e7c-e749-4db7-b346-cc662dceb0e7.jpg
#   inflating: images/a97c8cdf-ff23-4568-9c6b-6942d0d5d7e0.jpg
#   inflating: images/a97d87d4-07b2-4974-a155-967daf509a06.jpg
#   inflating: images/a9829a73-f24e-4129-a8a3-c3c2f500c6f9.jpg
#   inflating: images/a984f2f3-e1f5-45b8-a024-66e4453ecb6b.jpg
#   inflating: images/a98a3c7c-616d-459c-a41a-dbf5553cbc29.jpg
#   inflating: images/a98d1c66-c005-4242-b954-c07748b8f356.jpg
#   inflating: images/a98e570b-99eb-48c8-b588-34062fefdc5f.jpg
#   inflating: images/a99ff4b5-c1c0-43e7-b642-27f38901795f.jpg
#   inflating: images/a9a272c8-e35e-4483-bbb7-0909ba179e9c.jpg
#   inflating: images/a9a40e63-a55b-4b20-a783-cc6a816f5e58.jpg
#   inflating: images/a9a55316-3b2b-47fa-9a79-4acabe7c84a5.jpg
#   inflating: images/a9a591b6-0725-4914-9e8d-eb03bdfc826b.jpg
#   inflating: images/a9a5edde-cc21-45aa-aeb2-3597165edd87.jpg
#   inflating: images/a9a8b36f-fc34-4de9-9364-5766ff29efe0.jpg
#   inflating: images/a9ab1774-0750-48c2-a33a-ba19fe06aba3.jpg
#   inflating: images/a9ac3259-8120-4d4d-a46f-e03728ed6b89.jpg
#   inflating: images/a9bf0c9d-aafd-4856-b212-7806ddcb31d5.jpg
#   inflating: images/a9c769ed-738b-41f1-a220-726473a3582e.jpg
#   inflating: images/a9c76cbe-e0a4-4b33-bc65-f3bfde114634.jpg
#   inflating: images/a9de0642-3d71-447d-a895-05e9d7cc3afc.jpg
#   inflating: images/a9ed5551-3f10-4c6c-a83c-9907cda711f9.jpg
#   inflating: images/a9edaf5b-b8c0-4efc-a5c6-2823497ec49b.jpg
#   inflating: images/a9f39f3f-f355-453d-a029-56aaa3f5c055.jpg
#   inflating: images/aa04a444-76b8-4c75-9c40-48700e6189b3.jpg
#   inflating: images/aa06d049-04d4-4bab-a2e9-f06ef583d4a9.jpg
# ...
#   inflating: images/fab09d7e-8374-4af4-9f93-1804e068b6a3.jpg
#   inflating: images/fab6861d-50b1-4bb4-b7ab-b189460f6fc5.jpg
#   inflating: images/fabdfaa4-9672-45d9-97f4-bd912ea07560.jpg
#   inflating: images/fabe3171-c06a-4866-9c01-72b1050b6acb.jpg
#   inflating: images/fac31566-a8c1-4a5d-88cb-1ff24fc2cb0d.jpg
#   inflating: images/facc9aef-905a-4f5a-8bd1-dcdf22df4385.jpg
#   inflating: images/fad67c8f-5912-4a3f-83f9-1ce13d83a6dc.jpg
#   inflating: images/fad82432-72e4-4c04-a9f1-e497daf86dfe.jpg
#   inflating: images/fadcd546-e658-4c6d-998e-98166e09946a.jpg
#   inflating: images/fadd93e1-c4e5-4888-b573-f8950a2d02d0.jpg
#   inflating: images/fadf009e-43f3-4d65-ba95-3eb151720159.jpg
#   inflating: images/fae2a69f-44ef-4fcb-bd98-e6828459c4bd.jpg
#   inflating: images/faefbb17-12d4-4040-b4bf-5784830cf4be.jpg
#   inflating: images/fafc3495-4adb-435b-99a7-9d47f3b03638.jpg
#   inflating: images/fafd317c-2176-448c-9174-5a57a4692f27.jpg
#   inflating: images/fb0111a2-1525-4709-bead-8e53570a8c7c.jpg
#   inflating: images/fb04087f-628f-4956-85df-acfeb7c242a4.jpg
#   inflating: images/fb0c927e-b7b5-4886-ac27-ef57ac5508c2.jpg
#   inflating: images/fb1f72e3-0254-44e2-a318-5d395710a70b.jpg
#   inflating: images/fb1f7a4d-34b2-43b9-ba54-17855ab17e19.jpg
#   inflating: images/fb238862-05bb-477f-98af-345451b884b6.jpg
#   inflating: images/fb26145e-c964-4695-b729-1db498108cf7.jpg
#   inflating: images/fb2a494b-f17b-426b-a903-5c360acd3508.jpg
#   inflating: images/fb2b64ed-8f5b-42a4-9b29-dadb6d3e4c41.jpg
#   inflating: images/fb304f1e-95cf-4c64-976e-622712690a9d.jpg
#   inflating: images/fb3521cf-9a36-4ef2-9777-d9f0d0290ef6.jpg
#   inflating: images/fb354f7d-eee0-4360-a626-8d30ad2fb184.jpg
#   inflating: images/fb36671e-d919-4bba-bb81-58c5c9d0afbb.jpg
#   inflating: images/fb40bd7e-9b41-4de7-b330-04e900e24362.jpg
#   inflating: images/fb4301ea-4f6f-48e2-83d6-9bb2b4902071.jpg
#   inflating: images/fb4449b0-5494-403e-8aae-253564419a23.jpg
#   inflating: images/fb447ac6-6453-48c3-9338-5dca8449a409.jpg
#   inflating: images/fb4944bc-7eb1-4df4-b00f-352bda93f9d1.jpg
#   inflating: images/fb4be6db-4301-4643-a7fc-a9c2f4913067.jpg
#   inflating: images/fb4d1ff5-3430-4370-bf03-8ae0d7d5d16d.jpg
#   inflating: images/fb4f9ec6-0347-44d3-889a-6f6ba5f63e80.jpg
#   inflating: images/fb5252a8-285d-435d-befe-10d47f306859.jpg
#   inflating: images/fb53513b-90bc-41af-a06d-db7131f7bc09.jpg
#   inflating: images/fb5503a9-eb5f-4f73-a953-bfb80d9137fb.jpg
#   inflating: images/fb5c9d68-73b9-4a52-a98a-d7d41f991fd0.jpg
#   inflating: images/fb6bb59d-a549-428b-9936-0a53c14dd08f.jpg
#   inflating: images/fb757cfd-65a1-434c-b5e1-7fa06e316418.jpg
#   inflating: images/fb780fe4-8ca9-426b-b4f9-3fa7d94de48d.jpg
#   inflating: images/fb7989b7-96cd-4a04-a505-258ba09833c8.jpg
#   inflating: images/fb87c0f3-0f2a-4658-a45a-38894699d8b4.jpg
#   inflating: images/fb902a99-38e9-49da-b81a-245513e7c149.jpg
#   inflating: images/fb9066a1-531b-4af7-90e6-0aacfd103d8f.jpg
#   inflating: images/fb9241c0-908e-4dd7-a847-d73b85cb094c.jpg
#   inflating: images/fb99918c-7921-4c8f-b8bc-43e4f627333e.jpg
#   inflating: images/fb9d0b8f-12bb-406d-86ca-3782d70494aa.jpg
#   inflating: images/fb9e6a12-19a6-4f31-a4ee-9709d551309f.jpg
#   inflating: images/fba3c73c-2f84-46ec-8d10-d043242b53a2.jpg
#   inflating: images/fba4b5c3-162d-4682-b65c-0941ce806314.jpg
#   inflating: images/fbaacb50-74a9-49b2-9be5-23ef00d75894.jpg
#   inflating: images/fbb71a67-9c02-4f4b-b25a-c968ded42e57.jpg
#   inflating: images/fbc967e8-37bd-43b4-8322-d45eb1979e1f.jpg
#   inflating: images/fbd53188-a961-4bda-bd8b-d7c9cd409811.jpg
#   inflating: images/fbdc4495-02c5-40b6-91da-ef3188f460de.jpg
#   inflating: images/fbdf8d3a-9361-4d60-bb61-2f3cb7442d13.jpg
#   inflating: images/fbdfa79d-38e2-4e5b-8643-9d0e100cb2b4.jpg
#   inflating: images/fbe4cf07-0c24-4b12-91b6-05d3d82c09ab.jpg
#   inflating: images/fbeb9d86-1d56-40ff-bc99-524e3aef4526.jpg
#   inflating: images/fbecebf6-d351-4562-b9b5-dd0530157374.jpg
#   inflating: images/fc05257d-d213-45bf-9d2d-7bfaa9bbdefa.jpg
#   inflating: images/fc0df24f-c6af-49a9-a567-30140889f368.jpg
#   inflating: images/fc0e9859-2f0e-4c52-953b-44bcd880b543.jpg
#   inflating: images/fc123b9d-7eed-4bc6-84bf-d92264c5aa21.jpg
#   inflating: images/fc138be2-8ec5-407d-931c-04d9a9aeac26.jpg
#   inflating: images/fc348b7b-be85-47bc-b043-d30345be7fce.jpg
#   inflating: images/fc37e00b-1b99-4392-8677-9169acf3adbf.jpg
#   inflating: images/fc3a883f-e4e8-4119-9cc4-53407bc7f219.jpg
#   inflating: images/fc3db1b9-fca5-4450-8452-a54078454715.jpg
#   inflating: images/fc449345-8c6e-4fc8-85c4-6cb5104da4bd.jpg
#   inflating: images/fc4af7b4-1c32-44b4-ab0b-d317925a9676.jpg
#   inflating: images/fc501977-eb07-4dbb-a164-bffeacd706b8.jpg
#   inflating: images/fc52e21e-6d9f-41ba-852d-d3376d6919cb.jpg
#   inflating: images/fc55e72b-4df3-46b2-95b7-4da1bd06c41c.jpg
#   inflating: images/fc56300e-e4d7-41ea-b65d-1412e130b7fa.jpg
#   inflating: images/fc5ab69b-1130-4011-85ba-1c5b9fd48654.jpg
#   inflating: images/fc5f0de0-9fbb-45b0-84d5-2f3893d59bcb.jpg
#   inflating: images/fc65c28e-2832-4339-b39e-44a0c60db5b5.jpg
#   inflating: images/fc69595e-0feb-4bc8-a7d2-e47965cf2bef.jpg
#   inflating: images/fc6c43e7-f932-4b52-a22f-faa46dabfd34.jpg
#   inflating: images/fc6d0615-a30b-4f75-b513-45d12b437250.jpg
#   inflating: images/fc705863-3250-4eb4-88b4-910e9c95a7c4.jpg
#   inflating: images/fc726030-b87e-4256-8482-ef30f0a452e9.jpg
#   inflating: images/fc72aae7-3c61-4439-8214-892e19322be7.jpg
#   inflating: images/fc7922d1-995b-4cab-994c-846b3f226ad4.jpg
#   inflating: images/fc82a86b-5cd0-4985-9ee1-3aafe754d6ca.jpg
#   inflating: images/fc85b488-cf95-4461-9105-ad8b5881719b.jpg
#   inflating: images/fc87da4a-8601-42ab-a929-1921ac642249.jpg
#   inflating: images/fc950db8-8c07-48f0-aa9a-358fb5aea13f.jpg
#   inflating: images/fc9fbb5b-a5ed-46c5-b9b0-310ef5b8b11a.jpg
#   inflating: images/fca18862-8968-4dfa-a98a-2decacc5b135.jpg
#   inflating: images/fca74982-3285-4d57-8347-74628e609ae1.jpg
#   inflating: images/fcb0f953-7a1a-4575-bada-24c5f7f44e8f.jpg
#   inflating: images/fcba8b14-4e0a-4482-ae90-e71ea3a26399.jpg
#   inflating: images/fcbbbc33-de60-4e14-bcc1-930653a610bc.jpg
#   inflating: images/fcbc1593-3dd4-4bdd-b101-f9ed89df9a63.jpg
#   inflating: images/fcbc16e9-535d-41c8-9505-b04fc6a97bb8.jpg
#   inflating: images/fcbedd58-dbe1-4a0d-9615-c41f66fb56bf.jpg
#   inflating: images/fcc668ec-d87e-41ef-a889-e05299994602.jpg
#   inflating: images/fcc9dc5b-68ae-4ba3-9a8b-8b8199b803a6.jpg
#   inflating: images/fccadf13-b90f-4cd7-92db-185f0055008a.jpg
#   inflating: images/fcd01452-206a-4802-9bff-2801dce1b4f4.jpg
#   inflating: images/fcd190c7-ff8e-4904-b396-550f91cf7903.jpg
#   inflating: images/fcd50aa7-b694-43da-b621-fcd61177be9d.jpg
#   inflating: images/fcde6866-e83b-40e7-ab50-a8fb53406a25.jpg
#   inflating: images/fcde68f2-e6c2-4946-bdd8-e47ff946b20b.jpg
#   inflating: images/fce97e83-e4ce-4140-adc9-d976c67c2d6c.jpg
#   inflating: images/fced2d36-e650-4db7-a8ea-6022f8c2a98f.jpg
#   inflating: images/fcf61a49-86d9-45f5-905c-2c49881a55e3.jpg
#   inflating: images/fcfdd45f-b538-4940-a5ba-96a93962ae24.jpg
#   inflating: images/fd07449d-c7d8-47d1-8ea7-24dd738a4d61.jpg
#   inflating: images/fd0b84ee-2a73-46aa-b9f6-6bcad0b58d05.jpg
#   inflating: images/fd0c0bd7-bf2e-4753-8972-f5b0a70889e8.jpg
#   inflating: images/fd0fc836-e014-4a74-bec9-b1ca49632f02.jpg
#   inflating: images/fd166a6f-f1cb-4067-bf74-a15f2e7ccf44.jpg
#   inflating: images/fd26bef3-d45a-4232-86a6-5ee8f85c8fae.jpg
#   inflating: images/fd2f38c3-1f67-47e9-8c67-ac139d81faac.jpg
#   inflating: images/fd34d53f-8d06-44c8-842f-b0e179776a83.jpg
#   inflating: images/fd3b3883-0a8b-4ba8-8338-e81439a3faab.jpg
#   inflating: images/fd4127bd-e880-4095-bfd7-9acad8c48e84.jpg
#   inflating: images/fd46cdf2-c2df-40bb-b7b5-462fa72aaefd.jpg
#   inflating: images/fd475e44-44a0-4e37-8b88-6c4b60ff7bcd.jpg
#   inflating: images/fd5026d0-b65b-4837-a6b7-3cbd2a41dd8e.jpg
#   inflating: images/fd50ff9d-6bb1-43e5-9475-22368ec4c1d7.jpg
#   inflating: images/fd510bb3-0fe4-4b56-9580-7d6651f85194.jpg
#   inflating: images/fd52492f-e9ca-4367-9c12-5e0bc6fa6a28.jpg
#   inflating: images/fd5f6179-20ae-4ca8-816a-3a924eb12f04.jpg
#   inflating: images/fd66ddce-be0e-4f1c-8a6d-9ae55eee92b1.jpg
#   inflating: images/fd6b8171-d39e-4928-8f61-2d905ae6f748.jpg
#   inflating: images/fd740813-d1be-4a07-a9d9-22f8b9d3fa8b.jpg
#   inflating: images/fd74f6a2-2cf2-443d-948c-67750961782e.jpg
#   inflating: images/fd7ef7b5-feff-4269-b2a4-11e28ecb9b60.jpg
#   inflating: images/fd7f493c-ac91-4480-ace3-78af8993c4c0.jpg
#   inflating: images/fd804b09-4edd-46cd-90fc-cda4ff7dbe9c.jpg
#   inflating: images/fd812b40-70b3-460e-908c-5d860ff73a22.jpg
#   inflating: images/fd869973-11e3-42e1-af39-aee16f896ea4.jpg
#   inflating: images/fd86bb4c-8ab4-44bc-8877-a1c34f3b6161.jpg
#   inflating: images/fd8da0bc-974a-4ba0-b97b-339ad1d60125.jpg
#   inflating: images/fd8dd444-3614-4cbb-adbd-dc97d0d0c8b1.jpg
#   inflating: images/fd8e7c90-9072-4a57-ab91-98a407d4dd2c.jpg
#   inflating: images/fd9184c1-2b53-491a-8dc3-e35f924ea69f.jpg
#   inflating: images/fd91dddd-aaec-4c61-a827-00e84d2b2831.jpg
#   inflating: images/fd92448a-a17a-42a7-a54a-89d75f1dbac7.jpg
#   inflating: images/fd98f38c-d1ad-41d4-8213-4dc76730933d.jpg
#   inflating: images/fd9a9a6e-a0aa-48fe-beea-0b91255407be.jpg
#   inflating: images/fda25735-4e44-41ac-a85d-0937c09376d2.jpg
#   inflating: images/fdabdd56-1dc9-4d94-b954-f925f0073693.jpg
#   inflating: images/fdad7e33-0b25-479b-ac44-875a44fec94f.jpg
#   inflating: images/fdb09476-3f61-4e79-b6d8-b4982cf4413a.jpg
#   inflating: images/fdb42b61-cd34-4da0-b9cd-e82cb09f147a.jpg
#   inflating: images/fdb691e6-d6b2-47a1-bbe2-818e9efbbf3d.jpg
#   inflating: images/fdbca4d4-b20f-4fcf-abcd-b2b1cf0f53c7.jpg
#   inflating: images/fdbcb40a-0c2e-466e-a9a9-60731f494d79.jpg
#   inflating: images/fdc5c803-5e08-40e7-bcdc-5436ef63cbc5.jpg
#   inflating: images/fdc88084-3fdf-4005-984b-ddf1147eb9f4.jpg
#   inflating: images/fdce9593-cc5e-4c6d-8348-8cc6bb08dd80.jpg
#   inflating: images/fdd3add8-1cbb-40c5-a7f8-d32830250081.jpg
#   inflating: images/fdd921ca-d4e9-44dc-a510-0907e69fe4c9.jpg
#   inflating: images/fddc2678-2b1e-4875-acf1-889f7cda4761.jpg
#   inflating: images/fddc94a5-79b2-4ae4-b213-b3dd46f78b2d.jpg
#   inflating: images/fde59fd7-679c-4df4-904e-3f233fd159e2.jpg
#   inflating: images/fde80571-b38b-4d06-9252-87115ebdb165.jpg
#   inflating: images/fde851af-6141-4d30-93f6-2e668ebb034f.jpg
#   inflating: images/fdf0c0b2-b289-4f8b-81f4-05e4f73609f6.jpg
#   inflating: images/fdfba8a2-3d6f-40f3-afd9-3c0e72cb13c5.jpg
#   inflating: images/fdfe8474-6241-4c1a-b6bc-cf68e78dadf6.jpg
#   inflating: images/fe112923-ab8b-420e-ad65-fe59254cf2ec.jpg
#   inflating: images/fe1be312-35d9-45bb-b28f-b58e20ea8785.jpg
#   inflating: images/fe1bf29d-28f9-4d86-bacb-abb50bb65e7c.jpg
#   inflating: images/fe1d6960-1618-4f7f-9cac-4bd3ebdc7dc0.jpg
#   inflating: images/fe20c619-825a-4514-af30-4921f78d23ac.jpg
#   inflating: images/fe23b893-1e08-42fe-8f2b-f41186370208.jpg
#   inflating: images/fe274292-6178-486f-933a-84eab12df075.jpg
#   inflating: images/fe2a2631-aea3-4d99-abca-0e61734f80aa.jpg
#   inflating: images/fe36e18e-9424-4f02-a22a-ffb192799804.jpg
#   inflating: images/fe3ccd6e-f6ab-4d11-baf6-94571f12f206.jpg
#   inflating: images/fe3e5010-b4a6-4804-8e48-533066c97c36.jpg
#   inflating: images/fe4750ae-e951-4bcf-89de-f4d7a8c10d75.jpg
#   inflating: images/fe5844e9-b1d8-4afa-a799-6f8058baffe2.jpg
#   inflating: images/fe6ea036-e26a-4468-b71b-b258ec98eebc.jpg
#   inflating: images/fe74eba0-78c4-401e-89e7-f0f5bbd38dc3.jpg
#   inflating: images/fe76e705-1a5d-48b0-80f7-a58719969a99.jpg
#   inflating: images/fe76f55c-fa10-4993-922d-4d11855652d8.jpg
#   inflating: images/fe789031-1ebb-4b5d-8432-278194df780b.jpg
#   inflating: images/fe829690-85a2-4db7-a3dc-5c21604a1ee9.jpg
#   inflating: images/fe8c4dee-e178-4bba-96e7-839f0629a8c3.jpg
#   inflating: images/fe92b41f-a6e2-43be-9809-4133fae04c4c.jpg
#   inflating: images/fe93a96b-9abd-4115-a9c4-c7ba10e716d9.jpg
#   inflating: images/fea02f98-e2e0-4e63-8c6d-9b5671a48af7.jpg
#   inflating: images/fea0b6ca-87d1-4079-80af-d1dd7b4a4838.jpg
#   inflating: images/feb01212-2cba-4ea8-a7a1-260c867cb0dc.jpg
#   inflating: images/feb625cd-2870-44b6-b6c7-8c0d8d9c577b.jpg
#   inflating: images/feb6ad33-34c5-42ff-a23c-32290c533fa2.jpg
#   inflating: images/feb86c69-2ac0-4b08-9e6e-a019439866f7.jpg
#   inflating: images/feb8ccde-db8c-4b45-8c17-ddcf12db4e6e.jpg
#   inflating: images/feba922d-42e3-4bbf-8b51-db07cd7633db.jpg
#   inflating: images/febe95ad-906d-45e9-99f3-c88060af4e16.jpg
#   inflating: images/fec25d0a-b33a-481c-867b-0ed44758d23f.jpg
#   inflating: images/fec364a1-eb49-4c45-93da-b8eff68b6571.jpg
#   inflating: images/fec6026a-8fe8-415a-bb88-93577826a89b.jpg
#   inflating: images/fed5e03c-b77b-4e77-a784-fc4a33c082e2.jpg
#   inflating: images/fed6aafd-4bf5-4924-b760-5b9765135b80.jpg
#   inflating: images/fed78da2-8856-46a3-a140-8acc7b7ba6ea.jpg
#   inflating: images/fed7afe8-3fcb-48b1-ae15-cc03c3582569.jpg
#   inflating: images/fedb3844-9bc7-40e6-b634-8e5123de5b7c.jpg
#   inflating: images/fee362f5-1559-4148-b020-b018ddd3be19.jpg
#   inflating: images/feec42a8-2561-43bf-bfe3-99a6511d1538.jpg
#   inflating: images/fef0bd4d-e2f1-47d9-a372-37398709ae51.jpg
#   inflating: images/fef13d36-1003-4389-b26e-45779f9e3b94.jpg
#   inflating: images/fef559db-d1da-4386-ae95-5be957af0b0c.jpg
#   inflating: images/ff015d7b-3f9d-44b7-b04a-fcf896bb24a5.jpg
#   inflating: images/ff0d3022-036c-485e-afd7-4d11cf5d5d89.jpg
#   inflating: images/ff1185d5-dcb5-44df-931d-bef88bfa21ef.jpg
#   inflating: images/ff20872f-0081-419d-9f56-5abd559dcce7.jpg
#   inflating: images/ff234b31-775d-4220-bb36-dc4a008083c1.jpg
#   inflating: images/ff3aee22-10a9-4142-9290-737f0112c885.jpg
#   inflating: images/ff3ba11a-32d9-44e1-a3f2-2d5c5d052c77.jpg
#   inflating: images/ff433de0-8419-4e42-a1d0-7eaeeb61ced0.jpg
#   inflating: images/ff456b41-3447-4a51-aafc-722589631874.jpg
#   inflating: images/ff5287c8-3ac0-4f0f-8a19-f4353e562ca5.jpg
#   inflating: images/ff58a721-2f98-4a7d-94f7-a1c03080335a.jpg
#   inflating: images/ff5b8dd2-5ab1-4d99-8dc4-f6b0306e84cb.jpg
#   inflating: images/ff62d026-06aa-4212-8c5c-e129615deb73.jpg
#   inflating: images/ff648a62-b91a-4a34-b28b-9255927c9097.jpg
#   inflating: images/ff6c384b-f399-428c-bfff-db6a522f3ae0.jpg
#   inflating: images/ff709c82-a83a-4d27-9a5e-c6eb698995c0.jpg
#   inflating: images/ff72e4c9-8ae9-4277-9e42-627920835f8a.jpg
#   inflating: images/ff73d62c-8c95-4902-a143-04447afc1c34.jpg
#   inflating: images/ff746ac3-6fca-47d5-84c0-e427ee35ec10.jpg
#   inflating: images/ff7888f7-b40e-4a70-88c6-1b15516f147e.jpg
#   inflating: images/ff91a7fe-48af-4a21-8ee2-32d54f294205.jpg
#   inflating: images/ffa15f1b-a70c-4ace-aa54-021af4150307.jpg
#   inflating: images/ffa2d3ab-386b-4936-9b8d-6fc5844950c5.jpg
#   inflating: images/ffa3eb7d-84bf-452a-9ad0-66aee1908274.jpg
#   inflating: images/ffaa2b0c-eb8b-4789-b290-a2becca0458e.jpg
#   inflating: images/ffb5155b-5808-4aa5-b0b6-53a8ce7a48f3.jpg
#   inflating: images/ffc1a076-8dda-42e9-8c8c-9a81454c22f6.jpg
#   inflating: images/ffc4626c-8b99-4867-b13e-e33b26da8745.jpg
#   inflating: images/ffc5018d-5cf2-461c-a265-1913b8b58025.jpg
#   inflating: images/ffc67317-794a-418d-b2ad-d66325f3aad6.jpg
#   inflating: images/ffcccfd5-cdab-4543-994e-2bd693f1d2f1.jpg
#   inflating: images/ffd4987e-7570-40e9-9d0b-6e762e079480.jpg
#   inflating: images/ffd6fe87-51c5-4430-ab4f-748f54e19638.jpg
#   inflating: images/ffe43a5c-27cb-4353-8d02-2d0e7300820f.jpg
#   inflating: images/ffed6a1f-b817-44eb-bd7c-f8df4edb2be5.jpg
#   inflating: images/fff1f011-e379-4a9b-8397-440c1b003969.jpg
#   inflating: images/fff2c7de-5e5f-4d88-bcac-356ba402122c.jpg
#   inflating: images/fff372f0-50a4-430f-9332-0a3de339e5ba.jpg
#   inflating: images/fff46d7a-f70e-49aa-b5a4-2d33ed869274.jpg
#   inflating: images/fff5a3d5-dda1-4a5d-9dad-de9980e9ce3f.jpg
#   inflating: test.csv
#   inflating: train.csv

# %%
def process_csv(csv_path, images_folder, output_base_folder, has_labels=False):
    df = pd.read_csv(csv_path)

    if not os.path.exists(output_base_folder):
        os.makedirs(output_base_folder)

    for index, row in df.iterrows():
        image_path = row['image_path']
        if has_labels:
            font = row.get('font', 'unknown_font')
            font_size = row.get('font_size', 'unknown_size')
            color = row.get('color', 'unknown_color').replace("#", "")

            class_folder = os.path.join(
                output_base_folder,
                color,
                font,
                f"size_{font_size}"
            )
            if not os.path.exists(class_folder):
                os.makedirs(class_folder)
        else:
            class_folder = output_base_folder

        source = os.path.join(images_folder, os.path.basename(image_path))
        destination = os.path.join(class_folder, os.path.basename(image_path))

        if os.path.exists(source):
            shutil.copy2(source, destination)
        else:
            print(f"File {os.path.basename(image_path)} does not exist in {images_folder}")

train_csv_path = '/content/train.csv'
test_csv_path = '/content/test.csv'
images_folder = '/content/images'

train_output_base_folder = '/content/train_pic'
test_output_base_folder = '/content/test_pic'

process_csv(train_csv_path, images_folder, train_output_base_folder, has_labels=True)
process_csv(test_csv_path, images_folder, test_output_base_folder, has_labels=False)

# %%
class MultiAlphabetDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.samples = []

        self.color_mapping = {'FF6666': 0, '0000FF': 1, 'A020F0': 2, 'DF3030': 3, '26E953': 4}
        self.font_mapping = {'Athiti-Regular': 0, 'Sarabun-Regular': 1, 'NotoSerifThai-Regular': 2,
                             'Kodchasan-Regular': 3, 'Prompt-Regular': 4, 'KhaosuayThin': 5, 'FkBeautyRegular': 6}
        self.font_size_mapping = {18: 0, 20: 1, 22: 2, 24: 3, 26: 4, 28: 5}

        for color_dir in os.scandir(root_dir):
            if color_dir.is_dir():
                color = color_dir.name
                for font_dir in os.scandir(color_dir.path):
                    if font_dir.is_dir():
                        font = font_dir.name
                        for size_dir in os.scandir(font_dir.path):
                            if size_dir.is_dir() and size_dir.name.startswith("size_"):
                                font_size = int(size_dir.name.split('_')[1])
                                for file in os.scandir(size_dir.path):
                                    if file.is_file():
                                        self.samples.append((file.path, font, font_size, color))

        print(f"Total samples found: {len(self.samples)}")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_path, font, font_size, color = self.samples[idx]
        image = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        # Encode labels as tensors
        font_encoded = torch.tensor(self.font_mapping.get(font), dtype=torch.long)
        font_size_encoded = torch.tensor(self.font_size_mapping.get(font_size), dtype=torch.long)
        color_encoded = torch.tensor(self.color_mapping.get(color), dtype=torch.long)

        return image, color_encoded, font_encoded, font_size_encoded

# %%
class ReverseIntensity:
  def __init__(self, threshold=150):
    self.threshold = threshold

  def __call__(self, image):

    if isinstance(image, Image.Image):
      image_np = np.array(image)
    elif isinstance(image, np.ndarray):
      image_np = image
    else:
      raise TypeError("Unsupported type. Expected PIL Image or numpy array.")

    if np.mean(image_np) > self.threshold:
      reversed_image = 255 - image_np
      return Image. fromarray(reversed_image)
    else:
      return image

# %%
class MedianBlur(object):
    def __init__(self, kernel_size=1):
        self.kernel_size = kernel_size

    def __call__(self, img):
        img = img.filter(ImageFilter.MedianFilter(size=self.kernel_size))
        return img

##apply to all train test

# Define the transform pipeline
transform = transforms.Compose([
    transforms.CenterCrop((224, 224)),
    transforms.ColorJitter(contrast=0.1),
    transforms.ToTensor(),
])
root_dir = train_output_base_folder
dataset = MultiAlphabetDataset(root_dir=root_dir, transform=transform)

reverse_color_mapping = {v: k for k, v in dataset.color_mapping.items()}
reverse_font_mapping = {v: k for k, v in dataset.font_mapping.items()}
reverse_font_size_mapping = {v: k for k, v in dataset.font_size_mapping.items()}

dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

images, colors, fonts, font_sizes = next(iter(dataloader))

color_names = [reverse_color_mapping[int(color)] for color in colors]
font_names = [reverse_font_mapping[int(font)] for font in fonts]
font_size_names = [reverse_font_size_mapping[int(font_size)] for font_size in font_sizes]

print(f"Batch Images Shape: {images.shape}")
print(f"Batch Colors: {color_names}")
print(f"Batch Fonts: {font_names}")
print(f"Batch Font Sizes: {font_size_names}")
# Out:
# Total samples found: 10080
# Batch Images Shape: torch.Size([4, 3, 224, 224])
# Batch Colors: ['26E953', 'A020F0', '0000FF', 'DF3030']
# Batch Fonts: ['Prompt-Regular', 'Sarabun-Regular', 'KhaosuayThin', 'NotoSerifThai-Regular']
# Batch Font Sizes: [28, 28, 18, 20]

# %%
class RemoveWhiteNoiseAndBackground:
    def __init__(self, threshold=(200, 200, 200)):
            self.threshold = threshold

    def __call__(self, img):
            # Convert image to numpy array for pixel manipulation
            img_np = np.array(img)

            # Create a mask for pixels that are considered white noise or background
            mask = (img_np[..., 0] >= self.threshold[0]) & \
                (img_np[..., 1] >= self.threshold[1]) & \
                (img_np[..., 2] >= self.threshold[2])

            # Set those pixels to black (0, 0, 0)
            img_np[mask] = [255, 255, 255]

            # Convert back to PIL Image
            return Image.fromarray(img_np)
import cv2
class BilateralFilter:
    def __init__(self, d=9, sigmaColor=75, sigmaSpace=75):
        self.d = d
        self.sigmaColor = sigmaColor
        self.sigmaSpace = sigmaSpace

    def __call__(self, img):
        # Convert the PIL Image to a NumPy array
        img_np = np.array(img)

        # Apply the bilateral filter using OpenCV
        filtered_img_np = cv2.bilateralFilter(img_np, self.d, self.sigmaColor, self.sigmaSpace)

        # Convert the filtered NumPy array back to a PIL Image
        filtered_img = Image.fromarray(filtered_img_np)

        return filtered_img

# %%
def load_data(reverse=False, normalize=False, batch_size=32):
    root_dir = train_output_base_folder

    train_transform =transforms.Compose([
                    BilateralFilter(d=5, sigmaColor=60, sigmaSpace=60),
                    RemoveWhiteNoiseAndBackground(),
                    transforms.RandomAffine(degrees=(0),
                                            translate=(0.05, 0.05),
                                            scale=(1.0, 1.0),
                                            shear=0),
                    transforms.CenterCrop((64, 512)),
                    transforms.ToTensor(),
    ])

    dataset = MultiAlphabetDataset(root_dir=root_dir, transform=train_transform)

    train_size = int(0.8 * len(dataset))
    test_size = len(dataset) - train_size

    train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

    return train_loader, test_loader

# %%
train_loader, test_loader = load_data(reverse=False, normalize=False, batch_size=32)
# Out:
# Total samples found: 10080

# %%
# def get_dataset_stats(loader):
#     font_count = {}
#     font_size_count = {}
#     color_count = {}
#     total_samples = 0

#     reverse_color_mapping = {v: k for k, v in dataset.color_mapping.items()}
#     reverse_font_mapping = {v: k for k, v in dataset.font_mapping.items()}
#     reverse_font_size_mapping = {v: k for k, v in dataset.font_size_mapping.items()}

#     for batch in loader:
#         images, colors, fonts, font_sizes = batch

#         color_names = [reverse_color_mapping[int(color)] for color in colors]
#         font_names = [reverse_font_mapping[int(font)] for font in fonts]
#         font_size_names = [reverse_font_size_mapping[int(font_size)] for font_size in font_sizes]

#         for color in color_names:
#             if color not in color_count:
#                 color_count[color] = 0
#             color_count[color] += 1

#         for font in font_names:
#             if font not in font_count:
#                 font_count[font] = 0
#             font_count[font] += 1

#         for font_size in font_size_names:
#             if font_size not in font_size_count:
#                 font_size_count[font_size] = 0
#             font_size_count[font_size] += 1

#         total_samples += len(images)

#     return font_count, font_size_count, color_count, total_samples

# %%
# train_font_count, train_font_size_count, train_color_count, train_total_samples = get_dataset_stats(train_loader)
# test_font_count, test_font_size_count, test_color_count, test_total_samples = get_dataset_stats(test_loader)

# print("📃Train Dataset:")
# for font, count in train_font_count.items():
#     print(f"\tNumber of images with font {font}: {count}")
# for font_size, count in train_font_size_count.items():
#     print(f"\tNumber of images with font size {font_size}: {count}")
# for color, count in train_color_count.items():
#     print(f"\tNumber of images with color {color}: {count}")
# print(f"\tNumber of training samples: {train_total_samples}")

# print("📃Test Dataset:")
# for font, count in test_font_count.items():
#     print(f"\tNumber of images with font {font}: {count}")
# for font_size, count in test_font_size_count.items():
#     print(f"\tNumber of images with font size {font_size}: {count}")
# for color, count in test_color_count.items():
#     print(f"\tNumber of images with color {color}: {count}")
# print(f"\tNumber of testing samples: {test_total_samples}")

# %%
# TRAIN
color_name_map = {
    'FF6666': 'Pink',
    '0000FF': 'Blue',
    'A020F0': 'Purple',
    'DF3030': 'Red',
    '26E953': 'Green'
}
batch_size = 32
images, colors, fonts, font_sizes = next(iter(train_loader))

reverse_color_mapping = {v: k for k, v in dataset.color_mapping.items()}
reverse_font_mapping = {v: k for k, v in dataset.font_mapping.items()}
reverse_font_size_mapping = {v: k for k, v in dataset.font_size_mapping.items()}

fig, axes = plt.subplots(8, 4, figsize=(15, 24))
axes = axes.flatten()

for idx, (img, color, font, font_size) in enumerate(zip(images[:batch_size], colors[:batch_size], fonts[:batch_size], font_sizes[:batch_size])):
    ax = axes[idx]

    img_np = img.permute(1, 2, 0).numpy()

    color_name = reverse_color_mapping[int(color)]
    # color_hex = color_name_map[color_name]
    font_name = reverse_font_mapping[int(font)]
    font_size_value = reverse_font_size_mapping[int(font_size)]

    ax.imshow(img_np)
    ax.set_title(f"Font: {font_name}\nSize: {font_size_value}\nColor:#{color_name} {color_name_map[color_name]}")
    ax.axis('off')

for ax in axes[len(images[:batch_size]):]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# TEST
color_name_map = {
    'FF6666': 'Pink',
    '0000FF': 'Blue',
    'A020F0': 'Purple',
    'DF3030': 'Red',
    '26E953': 'Green'
}
batch_size = 32
images, colors, fonts, font_sizes = next(iter(test_loader))

reverse_color_mapping = {v: k for k, v in dataset.color_mapping.items()}
reverse_font_mapping = {v: k for k, v in dataset.font_mapping.items()}
reverse_font_size_mapping = {v: k for k, v in dataset.font_size_mapping.items()}

fig, axes = plt.subplots(8, 4, figsize=(15, 24))
axes = axes.flatten()

for idx, (img, color, font, font_size) in enumerate(zip(images[:batch_size], colors[:batch_size], fonts[:batch_size], font_sizes[:batch_size])):
    ax = axes[idx]

    img_np = img.permute(1, 2, 0).numpy()

    color_name = reverse_color_mapping[int(color)]
    # color_hex = color_name_map[color_name]
    font_name = reverse_font_mapping[int(font)]
    font_size_value = reverse_font_size_mapping[int(font_size)]

    ax.imshow(img_np)
    ax.set_title(f"Font: {font_name}\nSize: {font_size_value}\nColor:#{color_name} {color_name_map[color_name]}")
    ax.axis('off')

for ax in axes[len(images[:batch_size]):]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# model = models.vgg16(weights=models.VGG16_Weights.DEFAULT)

# %%
import torch
import torch.nn as nn
import torchvision.models as models

class CustomResNet(nn.Module):
    def __init__(self,
                 num_colors=5,
                 num_fonts=7,
                 num_sizes=6,
                 h_dims_color=[],
                 h_dims_font=[],
                 h_dims_size=[],
                 input_size=(3, 64, 512)):  # input_size is optional and unused for ResNet
        super(CustomResNet, self).__init__()

        self.resnet = models.resnet50(pretrained=True)

        # Freeze all layers except the fully connected layers
        for param in self.resnet.parameters():
            param.requires_grad = True

        # Replace the final fully connected layer
        in_features = self.resnet.fc.in_features
        self.resnet.fc = nn.Identity()  # Remove the fully connected layer

        self.color_classifier = self._create_classifier(in_features, h_dims_color, num_colors)
        self.font_classifier = self._create_classifier(in_features, h_dims_font, num_fonts)
        self.size_classifier = self._create_classifier(in_features, h_dims_size, num_sizes)

    def _create_classifier(self, in_features, h_dims, num_classes):
        layers = []
        for hdim in h_dims:
            layers.append(nn.Linear(in_features, hdim))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Dropout(p=0.25))
            in_features = hdim
        layers.append(nn.Linear(in_features, num_classes))
        return nn.Sequential(*layers)

    def forward(self, x):
        x = self.resnet(x)  # ResNet forward pass up to the final layer

        color_output = self.color_classifier(x)
        font_output = self.font_classifier(x)
        size_output = self.size_classifier(x)

        return color_output, font_output, size_output

# %%
num_colors = 5
num_fonts = 7
num_sizes = 6

# %%
best_score = 0.0

def calculate_fbeta_score(precision, recall, beta):
    beta_squared = beta ** 2
    return (1 + beta_squared) * (precision * recall) / ((beta_squared * precision) + recall + 1e-7)

def train(model,
          optimizer,
          train_loader,
          test_loader,
          epochs=10,
          beta=1,
          checkpoint_path=None,
          device='cpu'):
    global best_score
    model = model.to(device)
    print("🤖 Training on", device)

    for epoch in range(epochs):
        model.train()
        cross_entropy_loss = nn.CrossEntropyLoss()

        train_bar = tqdm(train_loader,
                         desc=f'🚀 Training Epoch [{epoch+1}/{epochs}]',
                         unit='batch')

        for batch_idx, (data, color_target, font_target, size_target) in enumerate(train_bar):
            data, color_target, font_target, size_target = data.to(device), color_target.to(device), font_target.to(device), size_target.to(device)

            optimizer.zero_grad()

            color_output, font_output, size_output = model(data)
            loss_color = cross_entropy_loss(color_output, color_target)
            loss_font = cross_entropy_loss(font_output, font_target)
            loss_size = cross_entropy_loss(size_output, size_target)

            loss = loss_color*0.5 + loss_font*1 + loss_size*1.5

            loss.backward()
            optimizer.step()

            train_bar.set_postfix(loss=loss.item())

        model.eval()


        correct_color, correct_font, correct_size = 0, 0, 0
        test_loss_color, test_loss_font, test_loss_size = 0, 0, 0

        all_color_preds, all_color_targets = [], []
        all_font_preds, all_font_targets = [], []
        all_size_preds, all_size_targets = [], []

        with torch.no_grad():
            test_bar = tqdm(test_loader,
                            desc=f"🧪 Testing Epoch [{epoch+1}/{epochs}]",
                            unit='batch')

            for data, color_target, font_target, size_target in test_bar:
                data, color_target, font_target, size_target = data.to(device), color_target.to(device), font_target.to(device), size_target.to(device)

                color_output, font_output, size_output = model(data)

                test_loss_color += cross_entropy_loss(color_output, color_target).item()
                test_loss_font += cross_entropy_loss(font_output, font_target).item()
                test_loss_size += cross_entropy_loss(size_output, size_target).item()

                color_pred = color_output.argmax(dim=1, keepdim=True)
                font_pred = font_output.argmax(dim=1, keepdim=True)
                size_pred = size_output.argmax(dim=1, keepdim=True)

                correct_color += color_pred.eq(color_target.view_as(color_pred)).sum().item()
                correct_font += font_pred.eq(font_target.view_as(font_pred)).sum().item()
                correct_size += size_pred.eq(size_target.view_as(size_pred)).sum().item()

                all_color_preds.extend(color_pred.cpu().numpy())
                all_color_targets.extend(color_target.cpu().numpy())
                all_font_preds.extend(font_pred.cpu().numpy())
                all_font_targets.extend(font_target.cpu().numpy())
                all_size_preds.extend(size_pred.cpu().numpy())
                all_size_targets.extend(size_target.cpu().numpy())

            test_loss_color /= len(test_loader.dataset)
            test_loss_font /= len(test_loader.dataset)
            test_loss_size /= len(test_loader.dataset)

            accuracy_color = 100. * correct_color / len(test_loader.dataset)
            accuracy_font = 100. * correct_font / len(test_loader.dataset)
            accuracy_size = 100. * correct_size / len(test_loader.dataset)

            precision_color = precision_score(all_color_targets, all_color_preds, average='weighted')
            recall_color = recall_score(all_color_targets, all_color_preds, average='weighted')
            precision_font = precision_score(all_font_targets, all_font_preds, average='weighted')
            recall_font = recall_score(all_font_targets, all_font_preds, average='weighted')
            precision_size = precision_score(all_size_targets, all_size_preds, average='weighted')
            recall_size = recall_score(all_size_targets, all_size_preds, average='weighted')

            fbeta_color = calculate_fbeta_score(precision_color, recall_color, beta)
            fbeta_font = calculate_fbeta_score(precision_font, recall_font, beta)
            fbeta_size = calculate_fbeta_score(precision_size, recall_size, beta)

            fbeta_total = (fbeta_font)*0.3 + (fbeta_color)*0.2 + (fbeta_size)*0.5

            print(f'Test set:')
            print(f'Average Color loss: {test_loss_color:.4f},🌈 F1: {fbeta_color:.4f}%')
            print(f'Average Font loss: {test_loss_font:.4f},🔤 F1: {fbeta_font:.4f}%')
            print(f'Average Size loss: {test_loss_size:.4f},🔢 F1: {fbeta_size:.4f}%')

            print(f'👽 Real Score (Total F-beta): {fbeta_total:.4f}')

            if fbeta_total > best_score:
                best_score = fbeta_total
                if checkpoint_path:
                    torch.save(model.state_dict(), checkpoint_path)
                    print(f'# 🧠 Best model saved with F-beta Score: {fbeta_total:.4f} at epoch {epoch+1} 🧠')

# %%
model = CustomResNet(num_colors, num_fonts, num_sizes, h_dims_color=[256, 128], h_dims_font=[1024, 512,256],h_dims_size=[2048,1024,512])
optimizer = torch.optim.Adam(model.parameters(), lr=0.00003)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train(model=model,
      optimizer=optimizer,
      train_loader=train_loader,
      test_loader=test_loader,
      epochs=45,
      beta=1,
      checkpoint_path="/content/best_model.pth",
      device=device)

print(f"😎 Best Score is {best_score:.4f}")
# Out:
# 🤖 Training on cuda
# 🚀 Training Epoch [1/45]: 100%|██████████| 252/252 [01:11<00:00,  3.53batch/s, loss=3.22]
# 🧪 Testing Epoch [1/45]: 100%|██████████| 63/63 [00:08<00:00,  7.71batch/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test set:
# Average Color loss: 0.0039,🌈 F1: 0.9832%
# Average Font loss: 0.0357,🔤 F1: 0.4458%
# Average Size loss: 0.0367,🔢 F1: 0.4710%
# 👽 Real Score (Total F-beta): 0.5659
# 🚀 Training Epoch [2/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=2.18]
# 🧪 Testing Epoch [2/45]: 100%|██████████| 63/63 [00:08<00:00,  7.82batch/s]
# Test set:
# Average Color loss: 0.0009,🌈 F1: 0.9980%
# Average Font loss: 0.0201,🔤 F1: 0.7332%
# Average Size loss: 0.0293,🔢 F1: 0.5893%
# 👽 Real Score (Total F-beta): 0.7142
# 🚀 Training Epoch [3/45]: 100%|██████████| 252/252 [01:11<00:00,  3.54batch/s, loss=1.74]
# 🧪 Testing Epoch [3/45]: 100%|██████████| 63/63 [00:07<00:00,  8.10batch/s]
# Test set:
# Average Color loss: 0.0005,🌈 F1: 0.9990%
# Average Font loss: 0.0149,🔤 F1: 0.8202%
# Average Size loss: 0.0252,🔢 F1: 0.6502%
# 👽 Real Score (Total F-beta): 0.7710
# 🚀 Training Epoch [4/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=1.25]
# 🧪 Testing Epoch [4/45]: 100%|██████████| 63/63 [00:07<00:00,  8.41batch/s]
# Test set:
# Average Color loss: 0.0003,🌈 F1: 0.9995%
# Average Font loss: 0.0095,🔤 F1: 0.8972%
# Average Size loss: 0.0219,🔢 F1: 0.7090%
# 👽 Real Score (Total F-beta): 0.8236
# 🚀 Training Epoch [5/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=1.56]
# 🧪 Testing Epoch [5/45]: 100%|██████████| 63/63 [00:07<00:00,  8.72batch/s]
# Test set:
# Average Color loss: 0.0002,🌈 F1: 0.9995%
# Average Font loss: 0.0052,🔤 F1: 0.9374%
# Average Size loss: 0.0220,🔢 F1: 0.7188%
# 👽 Real Score (Total F-beta): 0.8405
# 🚀 Training Epoch [6/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=1.07]
# 🧪 Testing Epoch [6/45]: 100%|██████████| 63/63 [00:06<00:00,  9.02batch/s]
# Test set:
# Average Color loss: 0.0004,🌈 F1: 0.9980%
# Average Font loss: 0.0048,🔤 F1: 0.9437%
# Average Size loss: 0.0241,🔢 F1: 0.6827%
# 👽 Real Score (Total F-beta): 0.8241
# 🚀 Training Epoch [7/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=0.893]
# 🧪 Testing Epoch [7/45]: 100%|██████████| 63/63 [00:06<00:00,  9.07batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9990%
# Average Font loss: 0.0029,🔤 F1: 0.9660%
# Average Size loss: 0.0179,🔢 F1: 0.7719%
# 👽 Real Score (Total F-beta): 0.8755
# 🚀 Training Epoch [8/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=0.933]
# 🧪 Testing Epoch [8/45]: 100%|██████████| 63/63 [00:06<00:00,  9.03batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 1.0000%
# Average Font loss: 0.0043,🔤 F1: 0.9525%
# Average Size loss: 0.0239,🔢 F1: 0.6678%
# 👽 Real Score (Total F-beta): 0.8196
# 🚀 Training Epoch [9/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.75]
# 🧪 Testing Epoch [9/45]: 100%|██████████| 63/63 [00:06<00:00,  9.02batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9990%
# Average Font loss: 0.0026,🔤 F1: 0.9721%
# Average Size loss: 0.0151,🔢 F1: 0.8103%
# 👽 Real Score (Total F-beta): 0.8966
# 🚀 Training Epoch [10/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=0.789]
# 🧪 Testing Epoch [10/45]: 100%|██████████| 63/63 [00:07<00:00,  8.92batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9985%
# Average Font loss: 0.0033,🔤 F1: 0.9599%
# Average Size loss: 0.0146,🔢 F1: 0.8244%
# 👽 Real Score (Total F-beta): 0.8999
# 🚀 Training Epoch [11/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=1.02]
# 🧪 Testing Epoch [11/45]: 100%|██████████| 63/63 [00:07<00:00,  8.78batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9995%
# Average Font loss: 0.0027,🔤 F1: 0.9724%
# Average Size loss: 0.0167,🔢 F1: 0.8038%
# 👽 Real Score (Total F-beta): 0.8935
# 🚀 Training Epoch [12/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=0.362]
# 🧪 Testing Epoch [12/45]: 100%|██████████| 63/63 [00:07<00:00,  8.37batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0024,🔤 F1: 0.9739%
# Average Size loss: 0.0137,🔢 F1: 0.8524%
# 👽 Real Score (Total F-beta): 0.9184
# 🚀 Training Epoch [13/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.856]
# 🧪 Testing Epoch [13/45]: 100%|██████████| 63/63 [00:07<00:00,  8.01batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0028,🔤 F1: 0.9700%
# Average Size loss: 0.0138,🔢 F1: 0.8301%
# 👽 Real Score (Total F-beta): 0.9061
# 🚀 Training Epoch [14/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.837]
# 🧪 Testing Epoch [14/45]: 100%|██████████| 63/63 [00:08<00:00,  7.85batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9990%
# Average Font loss: 0.0021,🔤 F1: 0.9778%
# Average Size loss: 0.0137,🔢 F1: 0.8385%
# 👽 Real Score (Total F-beta): 0.9124
# 🚀 Training Epoch [15/45]: 100%|██████████| 252/252 [01:09<00:00,  3.60batch/s, loss=0.649]
# 🧪 Testing Epoch [15/45]: 100%|██████████| 63/63 [00:07<00:00,  7.89batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9985%
# Average Font loss: 0.0041,🔤 F1: 0.9564%
# Average Size loss: 0.0124,🔢 F1: 0.8561%
# 👽 Real Score (Total F-beta): 0.9146
# 🚀 Training Epoch [16/45]: 100%|██████████| 252/252 [01:10<00:00,  3.60batch/s, loss=0.846]
# 🧪 Testing Epoch [16/45]: 100%|██████████| 63/63 [00:08<00:00,  7.87batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9995%
# Average Font loss: 0.0032,🔤 F1: 0.9702%
# Average Size loss: 0.0143,🔢 F1: 0.8313%
# 👽 Real Score (Total F-beta): 0.9066
# 🚀 Training Epoch [17/45]: 100%|██████████| 252/252 [01:09<00:00,  3.60batch/s, loss=0.577]
# 🧪 Testing Epoch [17/45]: 100%|██████████| 63/63 [00:07<00:00,  8.10batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9990%
# Average Font loss: 0.0023,🔤 F1: 0.9745%
# Average Size loss: 0.0115,🔢 F1: 0.8659%
# 👽 Real Score (Total F-beta): 0.9251
# 🚀 Training Epoch [18/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.522]
# 🧪 Testing Epoch [18/45]: 100%|██████████| 63/63 [00:07<00:00,  8.47batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0021,🔤 F1: 0.9818%
# Average Size loss: 0.0153,🔢 F1: 0.8374%
# 👽 Real Score (Total F-beta): 0.9132
# 🚀 Training Epoch [19/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.327]
# 🧪 Testing Epoch [19/45]: 100%|██████████| 63/63 [00:07<00:00,  8.76batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0039,🔤 F1: 0.9612%
# Average Size loss: 0.0110,🔢 F1: 0.8701%
# 👽 Real Score (Total F-beta): 0.9234
# 🚀 Training Epoch [20/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.764]
# 🧪 Testing Epoch [20/45]: 100%|██████████| 63/63 [00:07<00:00,  8.91batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9995%
# Average Font loss: 0.0025,🔤 F1: 0.9738%
# Average Size loss: 0.0130,🔢 F1: 0.8528%
# 👽 Real Score (Total F-beta): 0.9184
# 🚀 Training Epoch [21/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.344]
# 🧪 Testing Epoch [21/45]: 100%|██████████| 63/63 [00:06<00:00,  9.07batch/s]
# Test set:
# Average Color loss: 0.0002,🌈 F1: 0.9980%
# Average Font loss: 0.0019,🔤 F1: 0.9807%
# Average Size loss: 0.0123,🔢 F1: 0.8778%
# 👽 Real Score (Total F-beta): 0.9327
# 🚀 Training Epoch [22/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=0.677]
# 🧪 Testing Epoch [22/45]: 100%|██████████| 63/63 [00:06<00:00,  9.03batch/s]
# Test set:
# Average Color loss: 0.0006,🌈 F1: 0.9951%
# Average Font loss: 0.0027,🔤 F1: 0.9706%
# Average Size loss: 0.0156,🔢 F1: 0.8363%
# 👽 Real Score (Total F-beta): 0.9083
# 🚀 Training Epoch [23/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.61]
# 🧪 Testing Epoch [23/45]: 100%|██████████| 63/63 [00:07<00:00,  8.60batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0023,🔤 F1: 0.9759%
# Average Size loss: 0.0152,🔢 F1: 0.8501%
# 👽 Real Score (Total F-beta): 0.9178
# 🚀 Training Epoch [24/45]: 100%|██████████| 252/252 [01:09<00:00,  3.60batch/s, loss=0.898]
# 🧪 Testing Epoch [24/45]: 100%|██████████| 63/63 [00:07<00:00,  8.27batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0017,🔤 F1: 0.9822%
# Average Size loss: 0.0126,🔢 F1: 0.8723%
# 👽 Real Score (Total F-beta): 0.9308
# 🚀 Training Epoch [25/45]: 100%|██████████| 252/252 [01:10<00:00,  3.60batch/s, loss=0.352]
# 🧪 Testing Epoch [25/45]: 100%|██████████| 63/63 [00:07<00:00,  8.05batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 0.9995%
# Average Font loss: 0.0015,🔤 F1: 0.9827%
# Average Size loss: 0.0139,🔢 F1: 0.8476%
# 👽 Real Score (Total F-beta): 0.9185
# 🚀 Training Epoch [26/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.354]
# 🧪 Testing Epoch [26/45]: 100%|██████████| 63/63 [00:08<00:00,  7.63batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9975%
# Average Font loss: 0.0014,🔤 F1: 0.9866%
# Average Size loss: 0.0120,🔢 F1: 0.8807%
# 👽 Real Score (Total F-beta): 0.9358
# 🚀 Training Epoch [27/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.437]
# 🧪 Testing Epoch [27/45]: 100%|██████████| 63/63 [00:08<00:00,  7.86batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9990%
# Average Font loss: 0.0023,🔤 F1: 0.9744%
# Average Size loss: 0.0119,🔢 F1: 0.8750%
# 👽 Real Score (Total F-beta): 0.9296
# 🚀 Training Epoch [28/45]: 100%|██████████| 252/252 [01:09<00:00,  3.61batch/s, loss=0.0762]
# 🧪 Testing Epoch [28/45]: 100%|██████████| 63/63 [00:07<00:00,  8.04batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0018,🔤 F1: 0.9822%
# Average Size loss: 0.0109,🔢 F1: 0.8839%
# 👽 Real Score (Total F-beta): 0.9366
# 🚀 Training Epoch [29/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.157]
# 🧪 Testing Epoch [29/45]: 100%|██████████| 63/63 [00:07<00:00,  8.39batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0015,🔤 F1: 0.9832%
# Average Size loss: 0.0105,🔢 F1: 0.8994%
# 👽 Real Score (Total F-beta): 0.9447
# 🚀 Training Epoch [30/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.313]
# 🧪 Testing Epoch [30/45]: 100%|██████████| 63/63 [00:07<00:00,  8.69batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 0.9990%
# Average Font loss: 0.0020,🔤 F1: 0.9788%
# Average Size loss: 0.0171,🔢 F1: 0.8442%
# 👽 Real Score (Total F-beta): 0.9156
# 🚀 Training Epoch [31/45]: 100%|██████████| 252/252 [01:10<00:00,  3.60batch/s, loss=1.62]
# 🧪 Testing Epoch [31/45]: 100%|██████████| 63/63 [00:07<00:00,  8.73batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9995%
# Average Font loss: 0.0033,🔤 F1: 0.9701%
# Average Size loss: 0.0110,🔢 F1: 0.8923%
# 👽 Real Score (Total F-beta): 0.9371
# 🚀 Training Epoch [32/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.306]
# 🧪 Testing Epoch [32/45]: 100%|██████████| 63/63 [00:07<00:00,  8.94batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 0.9995%
# Average Font loss: 0.0023,🔤 F1: 0.9748%
# Average Size loss: 0.0107,🔢 F1: 0.8935%
# 👽 Real Score (Total F-beta): 0.9391
# 🚀 Training Epoch [33/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=0.364]
# 🧪 Testing Epoch [33/45]: 100%|██████████| 63/63 [00:06<00:00,  9.02batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 0.9995%
# Average Font loss: 0.0021,🔤 F1: 0.9782%
# Average Size loss: 0.0123,🔢 F1: 0.8777%
# 👽 Real Score (Total F-beta): 0.9322
# 🚀 Training Epoch [34/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=1.55]
# 🧪 Testing Epoch [34/45]: 100%|██████████| 63/63 [00:06<00:00,  9.00batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9990%
# Average Font loss: 0.0027,🔤 F1: 0.9744%
# Average Size loss: 0.0105,🔢 F1: 0.9005%
# 👽 Real Score (Total F-beta): 0.9424
# 🚀 Training Epoch [35/45]: 100%|██████████| 252/252 [01:10<00:00,  3.56batch/s, loss=0.0938]
# 🧪 Testing Epoch [35/45]: 100%|██████████| 63/63 [00:06<00:00,  9.06batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0021,🔤 F1: 0.9818%
# Average Size loss: 0.0108,🔢 F1: 0.8937%
# 👽 Real Score (Total F-beta): 0.9414
# 🚀 Training Epoch [36/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.477]
# 🧪 Testing Epoch [36/45]: 100%|██████████| 63/63 [00:06<00:00,  9.10batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9985%
# Average Font loss: 0.0015,🔤 F1: 0.9822%
# Average Size loss: 0.0147,🔢 F1: 0.8576%
# 👽 Real Score (Total F-beta): 0.9232
# 🚀 Training Epoch [37/45]: 100%|██████████| 252/252 [01:10<00:00,  3.57batch/s, loss=0.106]
# 🧪 Testing Epoch [37/45]: 100%|██████████| 63/63 [00:07<00:00,  8.88batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 0.9995%
# Average Font loss: 0.0011,🔤 F1: 0.9876%
# Average Size loss: 0.0097,🔢 F1: 0.8955%
# 👽 Real Score (Total F-beta): 0.9439
# 🚀 Training Epoch [38/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.567]
# 🧪 Testing Epoch [38/45]: 100%|██████████| 63/63 [00:07<00:00,  8.64batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9990%
# Average Font loss: 0.0015,🔤 F1: 0.9837%
# Average Size loss: 0.0123,🔢 F1: 0.8795%
# 👽 Real Score (Total F-beta): 0.9347
# 🚀 Training Epoch [39/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=0.407]
# 🧪 Testing Epoch [39/45]: 100%|██████████| 63/63 [00:07<00:00,  8.21batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0022,🔤 F1: 0.9793%
# Average Size loss: 0.0137,🔢 F1: 0.8688%
# 👽 Real Score (Total F-beta): 0.9282
# 🚀 Training Epoch [40/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.12]
# 🧪 Testing Epoch [40/45]: 100%|██████████| 63/63 [00:07<00:00,  7.98batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9990%
# Average Font loss: 0.0011,🔤 F1: 0.9896%
# Average Size loss: 0.0104,🔢 F1: 0.9035%
# 👽 Real Score (Total F-beta): 0.9484
# 🚀 Training Epoch [41/45]: 100%|██████████| 252/252 [01:10<00:00,  3.59batch/s, loss=0.164]
# 🧪 Testing Epoch [41/45]: 100%|██████████| 63/63 [00:07<00:00,  7.88batch/s]
# Test set:
# Average Color loss: 0.0001,🌈 F1: 0.9980%
# Average Font loss: 0.0021,🔤 F1: 0.9803%
# Average Size loss: 0.0116,🔢 F1: 0.9026%
# 👽 Real Score (Total F-beta): 0.9450
# 🚀 Training Epoch [42/45]: 100%|██████████| 252/252 [01:10<00:00,  3.60batch/s, loss=0.159]
# 🧪 Testing Epoch [42/45]: 100%|██████████| 63/63 [00:07<00:00,  7.96batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 0.9995%
# Average Font loss: 0.0018,🔤 F1: 0.9802%
# Average Size loss: 0.0191,🔢 F1: 0.8289%
# 👽 Real Score (Total F-beta): 0.9084
# 🚀 Training Epoch [43/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=0.504]
# 🧪 Testing Epoch [43/45]: 100%|██████████| 63/63 [00:07<00:00,  8.13batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0019,🔤 F1: 0.9822%
# Average Size loss: 0.0132,🔢 F1: 0.8670%
# 👽 Real Score (Total F-beta): 0.9282
# 🚀 Training Epoch [44/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=0.0735]
# 🧪 Testing Epoch [44/45]: 100%|██████████| 63/63 [00:07<00:00,  8.59batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0019,🔤 F1: 0.9797%
# Average Size loss: 0.0107,🔢 F1: 0.9079%
# 👽 Real Score (Total F-beta): 0.9479
# 🚀 Training Epoch [45/45]: 100%|██████████| 252/252 [01:10<00:00,  3.58batch/s, loss=0.291]
# 🧪 Testing Epoch [45/45]: 100%|██████████| 63/63 [00:07<00:00,  8.78batch/s]
# Test set:
# Average Color loss: 0.0000,🌈 F1: 1.0000%
# Average Font loss: 0.0019,🔤 F1: 0.9812%
# Average Size loss: 0.0105,🔢 F1: 0.9094%
# 👽 Real Score (Total F-beta): 0.9490
# 😎 Best Score is 0.9541

# %%
model = CustomResNet(num_colors, num_fonts, num_sizes, h_dims_color=[256, 128], h_dims_font=[1024, 512,256],h_dims_size=[2048,1024,512])
model.load_state_dict(torch.load("/content/best_model.pth"))

model.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

file_names, font_preds, size_preds, color_preds = [], [], [], []

submit_transform  = transforms.Compose([
    transforms.CenterCrop((224, 224)),
    BilateralFilter(d=5, sigmaColor=60, sigmaSpace=60),
    RemoveWhiteNoiseAndBackground(),
    transforms.CenterCrop((64, 512)),
    transforms.ToTensor(),
    ])

csv_file = '/content/test.csv'
df = pd.read_csv(csv_file)

file_paths_from_csv = df.iloc[:, 0]

reverse_color_mapping = {v: k for k, v in dataset.color_mapping.items()}
reverse_font_mapping = {v: k for k, v in dataset.font_mapping.items()}
reverse_font_size_mapping = {v: k for k, v in dataset.font_size_mapping.items()}

with torch.no_grad():
    submit_bar = tqdm(file_paths_from_csv, desc=f'📄 Submitting...', unit='image')
    for img_path in submit_bar:

        if not os.path.exists(img_path):
            print(f"File {img_path} does not exist.")
            continue
        image = Image.open(img_path).convert('RGB')
        image = submit_transform(image)
        image = image.unsqueeze(0).to(device)

        color_output, font_output, size_output = model(image)

        color_pred = color_output.argmax(dim=1, keepdim=True).item()
        color_preds.append(f"#{reverse_color_mapping[color_pred]}")

        font_pred = font_output.argmax(dim=1, keepdim=True).item()
        font_preds.append(reverse_font_mapping[font_pred])

        size_pred = size_output.argmax(dim=1, keepdim=True).item()
        size_preds.append(reverse_font_size_mapping[size_pred])

        file_name = os.path.basename(img_path)
        file_names.append(f"images/{file_name}")

data = list(zip(file_names, font_preds, size_preds, color_preds))
submission_df = pd.DataFrame(data, columns=['image_path', 'font', 'font_size', 'color'])

output_path = '/content/WorkShopSubmission.csv'
submission_df.to_csv(output_path, index=False)

print(f"CSV file saved to {output_path}")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 📄 Submitting...: 100%|██████████| 2520/2520 [00:34<00:00, 73.08image/s]
# CSV file saved to /content/WorkShopSubmission.csv
